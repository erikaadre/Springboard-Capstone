# %%
import pandas as pd
import requests
import numpy as np
import os

# %%
address = pd.read_csv('../data/name_address.csv')
concat_address = address.loc[:,'facility_address'] +', ' + address.loc[:,'facility_city'] +', '+ 'CA' +' '+address.loc[:,'facility_zip'].astype(str) 
address = pd.concat([address, concat_address.rename('concat_address')], axis = 1)

# %%
address.head()
# Out:
#     facility_name    program_name         facility_address    facility_city  \
# 0  GEN KOREAN BBQ  GEN KOREAN BBQ      24301 CRENSHAW BLVD         TORRANCE
# 1         DENNY'S         DENNY'S      15553 E VALLEY BLVD        LA PUENTE
# 2         TEA LAB         TEA LAB  18912 E GALE AVE STE #A  ROWLAND HEIGHTS
# 3    EL BOTANITAS    EL BOTANITAS         3614 MLK JR BLVD          LYNWOOD
# 4    POLLY'S PIES    POLLY'S PIES     17198 S NORWALK BLVD         CERRITOS
#
#    facility_zip                                     concat_address
# 0         90505            24301 CRENSHAW BLVD, TORRANCE, CA 90505
# 1         91744           15553 E VALLEY BLVD, LA PUENTE, CA 91744
# 2         91748  18912 E GALE AVE STE #A, ROWLAND HEIGHTS, CA 9...
# 3         90262                3614 MLK JR BLVD, LYNWOOD, CA 90262
# 4         90703           17198 S NORWALK BLVD, CERRITOS, CA 90703

# %%
# API AND HEADER CODE
api_key = ''
headers = {'Authorization': 'Bearer %s' % api_key}

# %%
# Function to extract Yelp ID from Yelp Business Match and insert into Yelp Business Details API

def get_business_details(name, address_1, city, state, country):
    ''' 
    Obtains ratings, review count, latitude/longitude, price, and restaurant categories 
    from Yelp Business Details Endpoint using the Yelp Business ID obtained from 
    Yelp Business Matches Endpoint
    
    name: name of business - string input
    address_1: Street Address e.g. 2436 Columbine Circle - string input
    city: city in abbreviated form e.g. CA - string input
    country: country - string input
    
    Yelp Only Allows for 5000 requests per day. This code calls upon the YELP API twice.
    '''
    
    # Get Yelp ID from Business Matches Endpoint
    url_bm = 'https://api.yelp.com/v3/businesses/matches'
    
    # Parameters for Business Match in Dictionary Format
    parameters_bm = {\
                 'name': name,\
                 'address1' : address_1,\
                 'city': city,\
                 'state': state,\
                 'country': country
             }
    
    # Call on Yelp Business Match API
    r_bm = requests.get(url = url_bm, params = parameters_bm, headers = headers)
    json_data_bm = r_bm.json()
    
    # Extract Yelp ID. 
    
    if (json_data_bm.get('businesses')==[]) == True:
        yelp_id = None
    else:
        yelp_id = json_data_bm['businesses'][0]['id']

    
    # Call on Yelp Business Details API to get necessary info
    url_bd = 'https://api.yelp.com/v3/businesses/{}'.format(yelp_id)
    
    
    # Yelp ID was not obtained, output would display None. If it has a yelp ID, fetch data from Yelp API
    if yelp_id == None:
        output = {
            'name': None,
            'address': None,
            'review_count': None,
            'rating' : None,
            'price': None,
            'categories': None,
            'latitude': None,
            'longitude': None,
            'yelp_id': None,
            'hours': None
    
}
    else:
        
        # Request info from Yelp Business Details Endpoint
        r_bd = requests.get(url = url_bd, headers = headers)
        json_data_bd = r_bd.json()
        
        answer = json_data_bd
        categories = [sub['title'] for sub in answer.get('categories')]
        output = {
            'name': answer.get('name'),
            'address': ', '.join([str(elem)for elem in answer.get('location').get('display_address')]),
            'review_count': answer.get('review_count'),
            'rating' : answer.get('rating'),
            'price': answer.get('price'),
            'categories': ', '.join([str(elem) for elem in [sub['title'] for sub in answer.get('categories')]]),
            'latitude': answer.get('coordinates').get('latitude'),
            'longitude': answer.get('coordinates').get('longitude'),
            'yelp_id': answer.get('id')
    
}
    output['name_input'] = name
    output['address_input'] = address_1
    output['city_input'] = city
    
    return output

# %%
# Testing if code works
get_business_details(address.iloc[2,1], address.iloc[2,2], address.iloc[2,3], 'CA', 'US')
# Out:
# {'name': "Denny's",
#  'address': '15553 Valley Blvd, La Puente, CA 91744',
#  'review_count': 92,
#  'rating': 2.5,
#  'price': '$',
#  'categories': 'Diners, Breakfast & Brunch, American (Traditional)',
#  'latitude': 34.0207864,
#  'longitude': -117.9586692,
#  'yelp_id': 'U8Gfec-186rQ93-3jbLdCQ',
#  'name_input': "DENNY'S",
#  'address_input': '15553 E VALLEY BLVD',
#  'city_input': 'LA PUENTE'}

# %%
# Create For Loop To Iterate Over 

# Create a list out of the columns of interest
# Since there is a daily limit of 5000 calls per day will. Need to slice the list in appropriate increments

res_name = (address['program_name']).tolist()[100:501]
res_address = (address['facility_address']).tolist()[100:501]
res_city = (address['facility_city'].tolist())[100:501]

# Output File Name
output_filename = '../data/yelp_data_100to501.csv'

results = []

for name, address_1, city in zip(res_name, res_address, res_city):
    bd_results = get_business_details(name, address_1, city, 'CA', 'US')
    results.append(bd_results)
    
    if len(results) % 500 == 0:
        pd.DataFrame(results).to_csv("{}_bak".format(output_filename))
        
# Convert list result to dataframe
pd.DataFrame(results).to_csv(output_filename, encoding = 'utf8')

# %%
## Ignore Beyond This Point!

# %%
res_name = (address['program_name']).tolist()
res_address = (address['facility_address']).tolist()
res_city = (address['facility_city'].tolist())
res_address
# Out:
# ['24301 CRENSHAW BLVD',
#  '15553 E VALLEY BLVD',
#  '18912 E GALE AVE STE #A',
#  '3614 MLK JR BLVD',
#  '17198 S NORWALK BLVD',
#  '1320 N VINE ST',
#  '7445 SUNSET BLVD # B',
#  '1250 E HARVARD RD',
#  '2114 S SAWTELLE BLVD # 211',
#  '9811 SANTA MONICA BLVD',
#  '18427 S AVALON BLVD',
#  '307 LINCOLN BLVD',
#  '305 E 8TH ST 103',
#  '618 SHOPPERS LN',
#  'OLVERA ST E17',
#  '1460 3RD ST',
#  '20311 VALLEY BLVD E',
#  '12440 E IMPERIAL HWY',
#  '1133 GLENOAKS BLVD #A',
#  '9727 CULVER BLVD',
#  '2350 E 223RD ST',
#  '700 S SANTA FE AVE',
#  '1802 E HUNTINGTON DR STE #B',
#  '134 S JAPANESE VILLAGE PLZ',
#  '3321 W BURBANK BLVD',
#  '738 ROSE AVE',
#  '1455 W 3RD ST',
#  '1555 W SEPULVEDA BLVD',
#  '2881 GAGE AVE',
#  '3020 W MAIN ST',
#  '13720 E RAMONA BLVD',
#  '2615 E CARSON ST',
#  '22300 S AVALON CIR',
#  '4315 N PECK RD',
#  '23705 HAWTHORNE BLVD',
#  '5523 E SOUTH ST',
#  '6333 W 3RD ST 336',
#  '1201 W VENICE BLVD',
#  '317 S BROADWAY ST 101E1',
#  'OLVERA ST 26',
#  '21812 VENTURA BLVD',
#  '970 N WESTERN AVE',
#  '1001 N S F BLVD UNIT 110',
#  '15330 AMAR RD',
#  '223 BROADWAY ST',
#  '4749 COLDWATER CANYON BLVD',
#  '5300 LNKERSHIM BLVD # 160',
#  '18207 E GALE AVE',
#  '970 GAYLEY AVE',
#  '497 E WASHINGTON BLVD',
#  '1106 HOPE ST',
#  '403 N PCH HWY STE 100',
#  '18409 S AVALON BLVD',
#  '541 S SPRING ST STE# 104',
#  '22332 S NORMANDIE AVE',
#  '2327 HONOLULU AVE',
#  '16022 E AMAR RD',
#  '2635 GAGE AVE',
#  '9340 E WHITTIER BLVD',
#  '416 FOOTHILL BLVD',
#  '22323 SHERMAN WAY',
#  '778 N NOGALES ST # E',
#  '5626 E WHITTIER',
#  '6000 E FLORENCE ST STE B-C',
#  '19927 GOLDEN VALLEY RD',
#  '3944 N PECK RD A1',
#  '3444 E MLK JR BLVD',
#  '11340 E 183RD ST',
#  '2401 E WHITTIER BLVD',
#  '794 MISSION BLVD',
#  '2536 S FIGUEROA ST',
#  '1307 E HUNTINGTON DR',
#  '11750 E WHITTIER BLVD',
#  '16028 E AMAR RD',
#  '12155 E FIRESTONE BLVD',
#  '9090 E IMPERIAL HWY',
#  '18361 S PIONEER BLVD',
#  '30817 THOUSAND OAKS BLVD',
#  '15344 E WHITTIER BLVD',
#  '23705 W MALIBU RD STE',
#  '6600 TPNG CYN BLVD UNIT FC06',
#  '6333 W 3RD ST #530',
#  '11714 BARRINGTON CT',
#  '1730 W SEPULVEDA BLVD 6',
#  '1723 E HUNTINGTON DR',
#  '1544 W FOOTHILL BLVD',
#  '3650 W MLK BLVD',
#  '5386 N CHERRY AVE',
#  '700 S ATLANTIC BLVD',
#  '4300 E CESAR CHAVEZ AVE',
#  '9588 LAKEWOOD',
#  '78 BERTH PORTS O CALL',
#  '2526 S FIGUEROA ST',
#  '11413 E SOUTH ST',
#  '15200 E VALLEY BLVD',
#  '14952 E VALLEY BLVD',
#  '8632 E VALLEY BLVD STE J&K',
#  '12950 VICTORY BLVD',
#  '150 W 3RD ST',
#  '10903 MAIN ST',
#  '15826 VENTURA BLVD # 110',
#  '11410 E SOUTH ST',
#  '16244 E WHITTIER BLVD',
#  '1243 S ALVARADO AVE # B-1',
#  '2345 HONOLULU AVE',
#  '303 S AZUSA AVE',
#  '12603 S NORWALK BLVD',
#  '18323 S PIONEER BLVD',
#  '1137 W AVENUE I',
#  '13405 E LAMBERT RD',
#  '112 WILSON AVE',
#  '9067 E IMPERIAL HWY',
#  '12000 WASHINGTON BLVD',
#  '10319 VENICE BLVD',
#  '135 N ARTSAKH AVE',
#  'OLVERA ST W17',
#  '407 N PCH HWY STE 100',
#  '240 LARCHMONT AVE',
#  '10928 MAIN ST',
#  '1063 E AVE J # 101',
#  '8662 E WHITTIER BLVD',
#  '1195 MISSION BLVD',
#  '2148 W VENICE BLVD',
#  '1121 HACIENDA BLVD',
#  '18559 DEVONSHIRE ST',
#  '2400 COUNTRY CLUB DR',
#  '1412 3RD ST',
#  '21901 ERWIN ST',
#  '8450 E VALLEY BLVD STE 116',
#  '7233 BEVERLY BLVD',
#  '4 GREEN PLEASURE PIER',
#  '231 9TH ST',
#  '1 N INDIAN HL # D-104',
#  '2310 PASADENA AVE STE # 102',
#  '811 W 7TH ST',
#  '11629 E VALLEY BLVD',
#  '7851 FOOTHILL BLVD',
#  '395 S TOPANGA BLVD',
#  '10316 E ALONDRA BLVD',
#  '1802 E HUNTINGTON DR',
#  '1428 HUNTINGTON DR # A',
#  '8024 ATLANTIC BLVD',
#  '29495 THE OLD RD',
#  '455 W FOOTHILL BLVD',
#  '1037 W TORRANCE BLVD',
#  '641 W REDONDO BEACH BLVD',
#  '12954 WASHINGTON BLVD',
#  '3650 W MARTIN LUTHER KING BLVD # 127',
#  '3358 DEL MAR AVE',
#  '327 LATIGO RD',
#  '10121 WHITTIER BLVD',
#  '2532 S FIGUEROA ST',
#  '18254 E GALE AVE',
#  '1003 E VALLEY BLVD',
#  '3525 CARSON BLVD VC07',
#  '3789 S CRENSHAW BLVD',
#  '9406 E ALONDRA BLVD',
#  '1129 W WASHINGTON BLVD',
#  '12017 E FIRESTONE BLVD',
#  '6600 TOPANGA CYN # 9028',
#  '5890 HOLLYWOOD BLVD',
#  '20240 S AVALON BLVD',
#  '26913 SIERRA HWY',
#  '1615 W MCKINLEY AVE',
#  '6530 LANKERSHIM BLVD STE A & B',
#  '317 S BROADWAY ST # A-6',
#  '126 N YALE AVE',
#  '109 N YALE AVE',
#  '310 N YALE AVE',
#  '1611 PACIFIC AVE',
#  '13356 ELDRIDGE AVE EAST CAMPUS',
#  '1260 S SOTO ST STE',
#  '18902 E GALE AVE # A',
#  '8600 E WHITTIER BLVD',
#  '1540 N VINE ST',
#  '601 S FAIR OAKS AVE',
#  '4100 BROADWAY',
#  '28005 SECO CYN',
#  '12623 S NORWALK BLVD',
#  '901 N GAREY AVE',
#  '3831 E MLK JR BLVD',
#  '17142 E COLIMA RD',
#  '3564 E MLK JR BLVD',
#  '1001 W MLK BLVD',
#  '3500 W 8TH ST',
#  '827 DOUGLAS ST',
#  '4200 PECK RD # E',
#  '988 HAMILTON RD',
#  '3320 SUNSET BLVD',
#  '6417 SELMA AVE',
#  '9635 LAUREL CANYON BLVD',
#  '325 N YALE AVE',
#  '15436 E WHITTIER BLVD',
#  '2035 N VERDUGO BLVD',
#  '11928 GARVEY AVE',
#  '24 W SIERRA MADRE',
#  '9301 E WHITTIER BLVD',
#  '14740 S BEACH BLVD',
#  '15126 S WESTERN',
#  '2704 E CARSON ST',
#  '3962 W ARTESIA BLVD',
#  '3650 W MARTIN LUTHER KING # 150',
#  '27706 MCBEAM PKWY',
#  '20305 S WESTERN AVE',
#  '5233 1/2 W SUNSET BLVD',
#  '11060 WASHINGTON BLVD STE A',
#  '1090 HUNTINGTON DR',
#  '150 S PACIFIC COAST HWY STE',
#  '9360 WILSHIRE BLVD',
#  '5449 ROSEMEAD BLVD',
#  '1427 3RD ST',
#  '18345 S PIONEER BLVD',
#  '0 GREEN PLEASURE PIER',
#  '2136 3RD ST',
#  '1101 W MCKINLEY AVE',
#  '141 CENTRAL AVE',
#  '1501 E HUNTINGTON DR',
#  '9219 E VALLEY BLVD',
#  '1131 1/2 S BREA CANYON',
#  '14816 S BEACH BLVD',
#  '15259 E AMAR RD',
#  '11819 WILSHIRE BLVD',
#  '900 W MLK JR BLVD',
#  '10961 E FIRESTONE BLVD',
#  '16915 S F MISSION BLVD',
#  '15928 VENTURA BLVD # 113',
#  '11424 E SOUTH ST',
#  '5333 Z00 DR',
#  '100 N CITRUS AVE',
#  '10408 W VENICE BLVD',
#  '20236 S AVALON BLVD',
#  '119 N ARTSAKH AVE',
#  '340 E FOOTHILL BLVD',
#  '21515 WESTERN AVE',
#  '17340 S PIONEER BLVD',
#  '3500 E MLK JR BLVD',
#  '15135 E AMAR RD',
#  '1600 S AZUSA AVE UNIT 169D',
#  '639 S SPRING ST',
#  '234 S PCH HWY STE #101',
#  '17625 CENTRAL AVE',
#  '3102 IMPERIAL HWY',
#  '11005 FIRESTONE ST # 112B',
#  '2387 LOMITA BLVD',
#  '3476 E WHITTIER BLVD',
#  '117 SECOND ST',
#  '7994 SUNSET BLVD',
#  '6333 W 3RD ST # 424',
#  '3100 IMPERIAL HWY # 3008',
#  '18007 E GALE AVE',
#  '9013 E VALLEY BLVD',
#  '750 W ROUTE 66 STE D & E',
#  '6420 ROSEMEAD BLVD',
#  '8264 SUNSET BLVD',
#  '1500 VERDUGO RD',
#  '18523 S AVALON BLVD',
#  '2005 W 7TH ST',
#  '16023 E AMAR RD',
#  '8500 BALBOA BLVD',
#  '8225 BEVERLY BLVD',
#  '1141 E BROADWAY AVE',
#  '12972 E LAKELAND RD',
#  '18614 S PIONEER BLVD',
#  '4131 WOODRUFF AVE',
#  '2223 BEVERLY',
#  '10201 RESEDA BLVD # 102',
#  '904 W ALAMEDA AVE',
#  '225 N YALE AVE',
#  '1000 UNIVERSAL CITY PLZ 130',
#  '1063 E AVE J # 103',
#  '1027 W MLK BLVD',
#  '5015 E DEL AMO BLVD',
#  '3464 MLK JR BLVD',
#  '317 S BROADWAY ST STAL D-1',
#  '120 7TH ST',
#  '342 E THOMAS ST',
#  '13079 E VALLEY BLVD',
#  '1381 E LAS TUNAS DR',
#  '4343 SPENCER ST',
#  '1253 N VINE ST SUIT 7A',
#  '2019 W VENICE BLVD',
#  '8700 BEVERLY BLVD PL LE',
#  '21042 S MAIN ST',
#  '1028 HUNTINGTON DR',
#  '20259 E VALLEY BLVD',
#  '6532 S GREENLEAF AVE',
#  '3705 SUNSET BLVD',
#  '16533 E WHITTIER BLVD',
#  '11770 E FIRESTONE BLVD',
#  '8620 E WHITTIER BLVD',
#  '2520 S FIGUEROA ST',
#  '410 8TH ST',
#  '2009 W ALAMEDA AVE',
#  '600 W 7TH # 160',
#  '4081 E WHITTIER BLVD',
#  '18246 E GALE RD #A',
#  '27776 N MCBEAN PKWY',
#  '12819 S CRENSHAW BLVD',
#  '13411 E IMPERIAL HWY',
#  '13844 E IMPERIAL HWY',
#  '2210 E PALMDALE BLVD',
#  '8866 CORBIN AVE',
#  '18612 S PIONEER BLVD',
#  '11835 WILSHIRE BLVD',
#  '6333 W 3RD ST # 316',
#  '533 ROSE AVE',
#  '2010 W J-8 AVE # 101',
#  '18210 E GALE AVE',
#  '9147 RESEDA BLVD',
#  '459 S AZUSA AVE # C',
#  '342 W PICO BLVD',
#  '2063 RANCHO VALLEY DR',
#  '9180 E WHITTIER BLVD',
#  '16436 S NORWALK BLVD',
#  '116 ARTSAKH AVE # 105',
#  '2250 PARK PL',
#  '4840 LANKERSHIM BLVD',
#  '9240 CULVER BLVD',
#  '6333 W 3RD ST E E-10',
#  '10729 E SOUTH ST',
#  '750 S TERRADO PLZ STE',
#  '1133 HACIENDA BLVD',
#  '3701 OCEAN VIEW BLVD A3',
#  '10641 SAN FERNANDO RD',
#  '6650 S CRENSHAW BLVD',
#  '3900 WILSHIRE BLVD',
#  '16138 S F MISSION BLVD',
#  '19117 S PIONEER BLVD',
#  '1391 SUNSET BLVD',
#  '18303 COLIMA RD # A',
#  '17104 S PIONEER BLVD',
#  '719 W COLUMBIA WAY',
#  '2071 RANCHO VALLEY DR # 100',
#  '3328 W 8TH ST',
#  '3512 W 8TH ST 111',
#  '9085 E IMPERIAL HWY',
#  '9361 E ALONDRA BLVD',
#  '3238 PICO BLVD',
#  '4279 CRENSHAW BLVD',
#  '5000 MARKET PLACE DR',
#  '19705 E COLIMA RD # 5',
#  '3101 W ARTESIA BLVD',
#  '14604 E RAMONA BLVD',
#  '307 6TH ST',
#  '15334 W WHITTIER # 6',
#  '6001 VERMONT AVE',
#  '1240 TRUMAN RD # 165',
#  '113 E 9TH ST',
#  '3525 W CARSON # 164-J',
#  '1610 E FOOTHILL BLVD',
#  '1115 W WASHINGTON BLVD # A',
#  '2209 E BASELINE RD # 500',
#  '19401 S VERMONT AVE # I-100',
#  '11840 S WILMINGTON AVE',
#  '2901 E WHITTIER BLVD STE K',
#  '8164 MELROSE AVE',
#  '419 N CANON DR',
#  '10769 SOUTH ST',
#  '136 E ARROW HWY',
#  '19321 VENTURA BLVD',
#  '2801 PICO BLVD',
#  '2901 OCEAN PARK BLVD STE 125',
#  '1037 S FLOWER ST',
#  '1868 E PALMDALE BLVD',
#  '4032 S WESTERN AVE',
#  '9051 TELEGRAPH RD',
#  '245 E ROWLAND ST',
#  '11136 LONG BEACH BLVD',
#  '7955 LAUREL CANYON BLVD',
#  '8406 LINCOLN BLVD',
#  '10721 BURBANK BLVD',
#  '2055 N TOWNE AVE',
#  '1649 W AVENUE K',
#  '14329 LAKEWOOD BLVD',
#  '6307 E WHITTIER BLVD',
#  '2429 W 190TH ST',
#  '5550 PEARBLOSSOM HWY',
#  '1750 SEPULVEDA BLVD',
#  '7450 BEVERLY BLVD',
#  '6648 LEXINGTON AVE',
#  '14543 E TELEGRAPH RD',
#  '122 N SAN FERNANDO BLVD',
#  '110 N SAN DIMAS AVE',
#  '11118 MAGNOLIA BLVD',
#  '331 W GARVEY AVE STE D',
#  '5818 TEMPLE CITY BLVD',
#  '9600 W BRIGHTON WAY',
#  '18679 DEVONSHIRE ST',
#  '11909 W PICO BLVD',
#  '8501 SEPULVEDA BLVD',
#  '2511 S VERMONT AVE',
#  '14920 RAYMER ST',
#  '4466 E LIVE OAK AVE',
#  '221 N GLENDORA AVE',
#  '8205 WOODMAN AVE STE 109',
#  '838 LINCOLN BLVD',
#  '9009 ALONDRA BLVD',
#  '11433 HAWTHORNE BLVD',
#  '3883 W CENTURY BLVD',
#  '8945 SANTA MONICA BLVD',
#  '1 COUNTRY CLUB DR',
#  '1625 SANTA ANITA AVE # 400',
#  '3850 BALDWIN AVE',
#  '17020 DEVONSHIRE ST',
#  '636 VENICE BLVD',
#  '1118 CYPRESS AVE',
#  '441 S CENTRAL AVE',
#  '10003 S NORMANDIE AVE',
#  '11446 JEFFERSON BLVD',
#  '1515 ABBOT KINNEY BLVD',
#  '2212 S ATLANTIC BLVD',
#  '307 E JEFFERSON BLVD',
#  '8118 GARVEY AVE STE I',
#  '16548 SOLEDAD CANYON RD',
#  '1845 W REDONDO BEACH BLVD',
#  '7319 S GREENLEAF AVE',
#  '22035 SHERMAN WAY',
#  '19300 RINALDI ST G&H',
#  '1356 ALLISON AVE',
#  '6721 ATLANTIC AVE',
#  '15023 ROSCOE BLVD',
#  '27984 SECO CANYON RD',
#  '428 AUTO CENTER DR',
#  '4849 VAN NUYS BLVD STE 101A',
#  '474 N BEVERLY DR',
#  '920 E VALLEY BLVD',
#  '2822 E AVENUE I',
#  '12036 LAKEWOOD BLVD',
#  '3756 W AVENUE 40 STE #NPQ',
#  '18612 VENTURA BLVD',
#  '1721 W SUNSET BLVD',
#  '10701 SEPULVEDA BLVD',
#  '7070 SEPULVEDA BLVD',
#  '1810 W SLAUSON AVE STE E',
#  '22651 VENTURA BLVD',
#  '4775 IRWINDALE AVE',
#  '8901 DE SOTO AVE',
#  '5833 KANAN RD',
#  '5220 W CENTINELA AVE',
#  '6701 W IMPERIAL HWY',
#  '3219 FIRESTONE BLVD',
#  '9136 SEPULVEDA BLVD',
#  '14847 BURBANK BLVD',
#  '548 W ARROW HWY',
#  '22214 PALOS VERDES BLVD',
#  '14304 E NELSON AVE',
#  '9383 WILSHIRE BLVD',
#  '15601 VENTURA BLVD',
#  '3607 W SUNSET BLVD',
#  '3031 S FIGUEROA ST',
#  '19044 LA PUENTE RD',
#  '13302 E ROSCRANS AVE',
#  '8425 S LA CIENEGA BLVD',
#  '8521 NORWALK BLVD STE F',
#  '901 S PRAIRIE AVE',
#  '2462 FOOTHILL BLVD',
#  '8280 W SUNSET BLVD',
#  '815 N CRISTOBAL AVE',
#  '8530 PARAMOUNT BLVD',
#  '1200 E MISSION BLVD',
#  '1858 DURFEE AVE',
#  '235 S 1ST ST',
#  '3351 W CENTURY BLVD STE 103',
#  '1520 AVIATION BLVD',
#  '2550 E AMAR RD STE A8',
#  '13439 OSBORNE ST',
#  '3901 PACIFIC COAST HWY STE D',
#  '2795 W AVENUE L',
#  '15301 VENTURA BLVD STE P6',
#  '2101 LINCOLN BLVD',
#  '2609 N MAIN ST',
#  '7353 MELROSE AVE STE #A',
#  '8136 W 3RD ST',
#  '3112 W SUNSET BLVD',
#  '7288 W SUNSET BLVD # 1A',
#  '943 W HUNTINGTON DR',
#  '16101 VENTURA BLVD STE 270',
#  '8841 1/2 LAS TUNAS DR',
#  '4201 W BEVERLY BLVD',
#  '2333 DALY ST',
#  '17221 PIONEER BLVD',
#  '7427 VAN NUYS BLVD',
#  '21095 GOLDEN SPRINGS DR',
#  '15400 HAWTHORNE BLVD STE #D',
#  '2542 E PALMDALE BLVD',
#  '1406 W 6TH ST',
#  '1830 E MARENGO ST',
#  '10632 LOWER AZUSA RD',
#  '1569 S FAIRWAY DR 126B&',
#  '15256 PARTHENIA ST',
#  '1925 W BADILLO ST',
#  '11701 W PICO BLVD',
#  '3920 SEPULVEDA BLVD',
#  '1113 GLENDALE GALLERIA',
#  '8060 E FLORENCE AVE',
#  '44054 W 10TH ST W',
#  '12080 VENTURA PL STE 5',
#  '955 W SEPULVEDA BLVD',
#  '5176 WILSHIRE BLVD',
#  '525 W 28TH ST',
#  '546 S SAN FERNANDO BLVD',
#  '2912 S SEPULVEDA BLVD',
#  '12936 SHERMAN WAY',
#  '8611 SANTA MONICA BLVD',
#  '12243 E ARTESIA BLVD',
#  '627 S GLENDALE AVE',
#  '11762 SAN VICENTE BLVD',
#  '1043 N HACIENDA BLVD',
#  '25343 WAYNE MILLS PL',
#  '4014 W WASHINGTON BLVD',
#  '6531 HOLLYWOOD BLVD',
#  '2750 E 1ST ST',
#  '706 1/2 FLORENCE AVE',
#  '6344 TOPANGA CANYON BLVD # 1075',
#  '11900 FOOTHILL BLVD',
#  '424 W FOOTHILL BLVD',
#  '7447 FIRESTONE BLVD',
#  '19070 LA PUENTE RD',
#  '102 S VERMONT AVE',
#  '3109 W OLYMPIC BLVD #D',
#  '14201 INGLEWOOD AVE',
#  '865 W ROUTE 66 STE #A',
#  '9039 BEVERLY BLVD',
#  '4000 WARNER BLVD',
#  '1050 S HILL ST',
#  '12924 RIVERSIDE DR',
#  '631 E ARROW HWY STE A',
#  '6101 W CENTURY BLVD',
#  '14455 VENTURA BLVD',
#  '1015 S NOGALES ST',
#  '2000 S ATLANTIC BLVD',
#  '4365 GLENCOE AVE',
#  '1639 S PALOS VERDES ST',
#  '410 MAIN ST',
#  '8322 S AVALON BLVD',
#  '1790 W CARSON ST',
#  '21540 HAWTHORNE BLVD 450A',
#  '11304 W PICO BLVD',
#  '3900 W MANCHESTER BLVD',
#  '1787 N VICTORY PL',
#  '450 E MANCHESTER BLVD',
#  '2095 S ATLANTIC BLVD STE H',
#  '19035 E COLIMA RD',
#  '15711 AMAR RD',
#  '3130 WILSHIRE BLVD STE #150',
#  '9624 GARVEY AVE',
#  '1631 S AZUSA AVE',
#  '17092 DEVONSHIRE ST',
#  '903 S VERMONT AVE',
#  '7639 E FIRESTONE BLVD',
#  '728 S ATLANTIC BLVD STE #102',
#  '10846 DOWNEY AVE',
#  '16858 DEVONSHIRE ST',
#  '1010 N GLENDALE AVE #100',
#  '18010 CHATSWORTH ST',
#  '725 S FIGUEROA ST # 131',
#  '8590 W SUNSET BLVD STE 12',
#  '6550 GREENLEAF AVE',
#  '13127 SAN FERNANDO RD # #101-',
#  '762 S VERMONT AVE',
#  '8048 W 3RD ST',
#  '853 AUTO CENTER DR # F',
#  '601 S ARDMORE AVE #100',
#  '5416 WHITSETT AVE',
#  '8610 VAN NUYS BLVD # 1104',
#  '223 W 6TH ST',
#  '23 WINDWARD AVE',
#  '1300 WILSHIRE BLVD',
#  '255 26TH ST STE 18',
#  '11104 W OLYMPIC BLVD',
#  '642 N BROADWAY STE #5',
#  '12065 BRANFORD ST',
#  '1208 W FRANCISQUITO AVE',
#  '17020 VENTURA BLVD',
#  '13324 VAN NUYS BLVD',
#  '201 E MAGNOLIA BLVD STE 154',
#  '311 W LOS FELIZ RD',
#  '2020 S BREA CANYON RD STE #A-2',
#  '6119 S FIGUEROA ST',
#  '10968 VENTURA BLVD',
#  '13148 E VALLEY BLVD',
#  '5306 ATLANTIC BLVD',
#  '5101 LANKERSHIM BLVD',
#  '1929 VERDUGO BLVD STE B',
#  '11456 TELEGRAPH RD',
#  '6801 HOLLYWOOD BLVD STE 325',
#  '3044 W TEMPLE AVE',
#  '133 N BANDINI ST',
#  '13651 ROSCOE BLVD',
#  '23925 NEWHALL RANCH RD',
#  '143 N MACLAY AVE',
#  '939 S FIGUEROA ST',
#  '442 W MANCHESTER AVE',
#  '24150 PARK SORRENTO',
#  '12806 S PRAIRIE AVE',
#  '230 S GAFFEY ST',
#  '641 W LANCASTER BLVD #105',
#  '4163 W 3RD ST',
#  '8340 VAN NUYS BLVD',
#  '8759 GLENOAKS BLVD',
#  '218 E ORANGE GROVE AVE',
#  '19920 VENTURA BLVD',
#  '333 S DIAMOND BAR BLVD',
#  '281 S THOMAS ST STE 103',
#  '4923 LANKERSHIM BLVD',
#  '1561 E AMAR RD',
#  '7247 N ROSEMEAD BLVD',
#  '8535 WASHINGTON BLVD UNIT A',
#  '4033 GAGE AVE',
#  '1818 CHARLIE SIFFORD DR',
#  '770 S GRAND AVE',
#  '380 WORLD WAY #6C4 -30',
#  '8941 CORBIN AVE',
#  '2505 E AVENUE S',
#  '1031 HERMOSA AVE',
#  '15006 S LA MIRADA BLVD',
#  '100 UNIVERSAL CITY PLZ',
#  '14926 CLARK AVE',
#  '350 S GRAND AVE STE R-3',
#  '1315 CENTINELA AVE',
#  '7008 S SAN PEDRO ST',
#  '14309 S ATLANTIC AVE STE 101',
#  '6333 BRISTOL PKWY',
#  '43543 20TH ST W',
#  '12032 BURBANK BLVD',
#  '2530 OVERLAND AVE',
#  '2200 W TEMPLE ST',
#  '1000 UNIVERSAL STUDIOS BLVD',
#  '4801 S AVALON BLVD',
#  '1015 S NOGALES ST STE #132',
#  '1253 N VINE ST STE #9',
#  '6212 GAGE AVE',
#  '1 INDUSTRY HILLS PKWY',
#  '3411 W OLYMPIC BLVD',
#  '25926 S WESTERN AVE',
#  '307 E JEFFERSON BLVD # 422',
#  '919 FOOTHILL AVE',
#  '8620 GARFIELD AVE',
#  '1 LMU DR MS 8420',
#  '1000 S LA BREA ST',
#  '11537 SHERMAN WAY',
#  '1846 LOMITA BLVD',
#  '8708 W PICO BLVD',
#  '227 W VALLEY BLVD STE 118B',
#  '2125 N SAN GABRIEL BLVD',
#  '13916 FRANCISQUITO AVE STE C',
#  '19649 VENTURA BLVD',
#  '1049 W MLK BLVD',
#  '350 CRENSHAW BLVD STE 101A',
#  '100 UCLA MEDICAL PLZ #170',
#  '13694 TELEGRAPH RD',
#  '10988 W PICO BLVD',
#  '1755 N HIGHLAND AVE',
#  '17835 E GALE AVE',
#  '14517 GILMORE ST',
#  '16550 VENTURA BLVD #101',
#  '459 S AZUSA AVE STE C',
#  '15713 DOWNEY AVE',
#  '9225 LAS TUNAS DR',
#  '2408 W VICTORY BLVD',
#  '19305 VICTORY BLVD',
#  '4115 N PARAMOUNT BLVD',
#  '4375 GLENCOE AVE STE D4',
#  '8274 SANTA MONICA BLVD',
#  '2010 E FIRESTONE BLVD',
#  '12463 VICTORY BLVD',
#  '1200 GRAND CENTRAL AVE',
#  '300 S SPRING ST',
#  '22940 VANOWEN ST',
#  '108 E FLORENCE AVE',
#  '1459 N CITRUS AVE',
#  '13790 FOOTHILL BLVD STE 7',
#  '2100 LAUREL CANYON BLVD',
#  '10571 W PICO BLVD',
#  '4338 PACIFIC COAST HWY',
#  '24631 CRENSHAW BLVD # K',
#  '100 W COLORADO ST',
#  '410 MANHATTAN BEACH BLVD',
#  '24335 VICTORY BLVD STE C',
#  '4040 W WASHINGTON BLVD',
#  '1425 S NOGALES ST',
#  '5960 CRENSHAW BLVD',
#  '282 E MISSION BLVD',
#  '2359 FOOTHILL BLVD',
#  '201 SANTA MONICA BLVD',
#  '620 AMERICANA WAY',
#  '4325 GLENCOE AVE STE C4',
#  '3837 MAIN ST',
#  '11771 SANTA MONICA BLVD',
#  '10350 S LONG BEACH BLVD',
#  '1063 E ROUTE 66 AVE',
#  '1131 MANHATTAN AVE',
#  '606 BROADWAY AVE STE 101',
#  '6310 W 3RD ST',
#  '8782 SUNSET BLVD',
#  '123 S TOPANGA CANYON BLVD',
#  '14315 E AMAR RD',
#  '13020 PACIFIC PROMENADE # #A',
#  '1901 W SUNSET BLVD',
#  '1000 UNIVERSAL STUDIO BLVD STE M41',
#  '22601 PACIFIC COAST HWY STE 103',
#  '7060 HOLLYWOOD BLVD # #110',
#  '1132 HERMOSA AVE',
#  '4100 W PICO BLVD STE #10B',
#  '12531 ALONDRA BLVD',
#  '1122 S DIAMOND BAR BLVD',
#  '8833 SUNSET BLVD',
#  '18677 DEVONSHIRE ST',
#  '130 W STOCKER ST',
#  '12033 S HAWTHORNE BLVD',
#  '12010 RAMONA BLVD STE 2',
#  '150 S GRAND AVE STE #N',
#  '133 W GARVEY AVE # #C',
#  '19723 VENTURA BLVD',
#  '2616 CANDLEWOOD ST',
#  '315 N VERDUGO RD',
#  '548 S SPRING ST STE #106',
#  '425 S LOS ANGELES ST STE F',
#  '1238 N HACIENDA BLVD',
#  '6530 LANKERSHIM BLVD STE #L',
#  '155 S MAIN ST',
#  '1801 OCEAN FRONT WALK',
#  '25653 PACIFIC COAST HWY',
#  '6052 W OLYMPIC BLVD',
#  '11357 VALLEY BLVD',
#  '11906 WILSHIRE BLVD',
#  '5805 IMPERIAL HWY',
#  '10901 E IMPERIAL HWY',
#  '11719 E WHITTIER BLVD',
#  '10321 SEPULVEDA BLVD',
#  '138 N SAN FERNANDO BLVD',
#  '8948 SANTA MONICA BLVD',
#  '2201 W PICO BLVD # H',
#  '6820 EASTERN AVE',
#  '2807 MAIN ST',
#  '327 N BRAND BLVD',
#  '11736 166TH ST',
#  '13153 FOOTHILL BLVD',
#  '3407 S CRENSHAW BLVD',
#  '14551 TEMPLE AVE STE B',
#  '8826 MELROSE AVE',
#  '1111 S FIGUEROA ST',
#  '422 N FORD BLVD',
#  '1208 E HUNTINGTON DR',
#  '300 E ANGELENO AVE',
#  '701 W CESAR CHAVEZ AVE #107',
#  '1300 S GOLDEN WEST AVE',
#  '28 W MAIN ST',
#  '4821 LANKERSHIM BLVD',
#  '3110 MAIN ST STE #112',
#  '226 E SEPULVEDA BLVD',
#  '131 E 6TH ST',
#  '11212 GLENOAKS BLVD # B',
#  '216 W 9TH ST',
#  '8111 ROSECRANS AVE',
#  '2000 E OLYMPIC BLVD',
#  '18111 NORDHOFF ST # 3738',
#  '3281 WILSHIRE BLVD',
#  '7914 S AVALON BLVD',
#  '18846 NORWALK BLVD',
#  '2600 S VERMONT AVE',
#  '368 N LEMON AVE STE B',
#  '3615 MONTEREY AVE',
#  '1045 W ARROW HWY',
#  '2325 D ST',
#  '3914 W ROSECRANS AVE',
#  '10658 ZELZAH AVE',
#  '1800 W SUNSET BLVD',
#  '201 N CITRUS AVE',
#  '959 N BROADWAY',
#  '3105 WILSHIRE BLVD',
#  '4101 E SLAUSON AVE',
#  '8957 E BEVERLY BLVD',
#  '11540 SANTA MONICA BLVD # 101',
#  '3328 W 8TH ST',
#  '227 PILLSBURY ST',
#  '111 N ATLANCTIC BLVD # #350',
#  '6503 SEPULVEDA BLVD',
#  '19231 VENTURA BLVD',
#  '7228 S BROADWAY',
#  '310 N CITRUS AVE UNIT M',
#  '1636 W 25TH ST',
#  '11900 S LONG BEACH BLVD',
#  '9470 LAS TUNAS DR',
#  '12540 CENTRALIA ST',
#  '13207 GLADSTONE AVE STE B',
#  '1049 GAYLEY AVE',
#  '1013 S ALVARADO ST',
#  '13215 OSBORNE ST STE F',
#  '6775 SANTA MONICA BLVD # 7',
#  '2677 E FLORENCE AVE',
#  '6807 SEPULVEDA BLVD',
#  '3465 W 6TH ST STE C-130',
#  '944 E SLAUSON AVE',
#  '326 N GARFIELD AVE',
#  '934 W 23RD ST',
#  '6800 RESEDA BLVD STE A',
#  '1042 N HACIENDA BLVD',
#  '8330 SANTA MONICA BLVD',
#  '3660 WILSHIRE BLVD STE 120',
#  '1747 W EL SEGUNDO BLVD',
#  '6256 TOPANGA CANYON BLVD # 2280',
#  '4795 VINELAND AVE',
#  '11312 SOUTH ST',
#  '1200 W MANCHESTER BLVD',
#  '5106 S CENTRAL AVE S',
#  '229 S VERMONT AVE',
#  '24412 HAWTHORNE BLVD',
#  '807 E 12TH ST # 248',
#  '2261 E MAPLE AVE',
#  '701 W AVENUE K STE 109',
#  '3616 W 3RD ST',
#  '1625 CABRILLO AVE',
#  '1550 MURCHISON AVE',
#  '2097 N TOWNE AVE',
#  '5567 W MANCHESTER AVE',
#  '26101 MAGIC MOUNTAIN PKWY',
#  '18912 NORWALK BLVD',
#  '14617 S CRENSHAW BLVD',
#  '6450 SEPULVEDA BLVD STE #B',
#  '3903 ROSECRANS BLVD',
#  '6118 BELLFLOWER BLVD',
#  '14440 FRIAR ST',
#  '2727 SANTA MONICA BLVD',
#  '2201 E CESAR E CHAVEZ AVE',
#  '1845 MONTEBELLO TOWN CTR',
#  '1221 ARTESIA BLVD',
#  '1317 E WASHINGTON BLVD',
#  '3155 GLENDALE BLVD',
#  '333 N VERDUGO RD',
#  '1020 E FLORENCE AVE',
#  '14212 E MULBERRY DR',
#  '4611 OLYMPIC BLVD',
#  '1253 N VINE ST',
#  '1032 W WEST COVINA PKWY',
#  '2370 S AZUSA AVE',
#  '12227 NORWALK BLVD',
#  '1050 S FLOWER ST STE 102',
#  '11907 W OLYMPIC BLVD',
#  '4964 W 190TH ST',
#  '1201 S FIGUEROA ST',
#  '9876 WILSHIRE BLVD',
#  '18427 NORDHOFF ST STE #D',
#  '6541 HOLLYWOOD BLVD # 104-0',
#  '10120 CARMENITA RD',
#  '2707 N MAIN ST',
#  '680 S AZUSA AVE # A',
#  '2150 W SUNSET BLVD',
#  '21095 GOLDEN SPRING DR',
#  '530 S CITRUS AVE STE 7',
#  '7404 FLORENCE AVE',
#  '523 ROSE AVE',
#  '1279 N HACIENDA BLVD',
#  '14059 VICTORY BLVD',
#  '1820 W SLAUSON AVE',
#  '555 E HARDY ST',
#  '12181 W BLUFF CREEK DR # A',
#  '40187 E 170TH ST E STE #A',
#  '3058 RANDOLPH ST',
#  '555 S AVIATION BLVD',
#  '100 WORLD WAY',
#  '30770 RUSSELL RANCH RD',
#  '321 E ALAMEDA AVE # P',
#  '23744 S MAIN ST',
#  '398 WRIGLEY RD',
#  '5711 W CENTURY BLVD',
#  '13737 INGLEWOOD AVE # #9',
#  '3435 WILSHIRE BLVD STE #160',
#  '2430 FULLERTON RD',
#  '6099 W SUNSET BLVD',
#  '10526 S WESTERN AVE',
#  '9936 COMMERCE AVE',
#  '14653 VICTORY BLVD',
#  '2331 ORANGE AVE',
#  '662 N SEPULVEDA BLVD',
#  '26441 BOUQUET CANYON RD',
#  '19800 S VERMONT AVE',
#  '400 N CANON DR',
#  '502 FOOTHILL BLVD',
#  '6257 BRISTOL PKWY',
#  '12930 VENTURA BLVD #106',
#  '8031 VINELAND AVE',
#  '11001 W PICO BLVD',
#  '20115 SHERMAN WAY',
#  '8221 WOODMAN AVE',
#  '8453 RESEDA BLVD',
#  '1951 N HOLLYWOOD WAY',
#  '233 E FLORENCE AVE',
#  '11600 E ALONDRA BLVD',
#  '9537 LAS TUNAS DR',
#  '6900 S SAN PEDRO ST',
#  '3150 OCEAN PARK BLVD # A',
#  '7102 FOOTHILL BLVD',
#  '12630 1/2 WASHINGTON PL',
#  '4488 E LIVE OAK AVE',
#  '100 UNIVERSAL CITY PLZ',
#  '8335 ROSECRANS AVE',
#  '13721 BURBANK BLVD',
#  '150 S PACIFIC COAST HWY STE A',
#  '17100 SIERRA HWY',
#  '4400 1/2 S AVALON BLVD',
#  '1501 FIRESTONE BLVD',
#  '1212 S STANFORD AVE STE 101',
#  '12801 BELLFLOWER BLVD',
#  '23420 HAWTHORNE BLVD',
#  '1362 E HUNTINGTON DR',
#  '18317 E COLIMA RD',
#  '12116 VANOWEN ST',
#  '148 W CARSON ST',
#  '405 N PACIFIC COAST HWY',
#  '1600 FOOTHILL BLVD',
#  '100 CITADEL DR #103',
#  '1418 S PACIFIC COAST HWY',
#  '12051 VENTURA PL',
#  '3084 MOTOR AVE',
#  '1542 SAN FERNANDO RD',
#  '4836 HUNTINGTON DR S',
#  '8264 SUNSET BLVD',
#  '17701 PIONEER BLVD',
#  '6669 HOLLYWOOD BLVD',
#  '28700 ROADSIDE DR',
#  '1224 W PACIFIC COAST HWY',
#  '950 E 33RD ST',
#  '11900 SOUTH ST STE 105',
#  '4130 N PARAMOUNT BLVD',
#  '4483 E WHITTIER BLVD',
#  '5540 E WHITTIER BLVD',
#  '11908 SAN VICENTE BLVD',
#  '3009 HONOLULU AVE',
#  '5305 N FIGUEROA ST',
#  '6718 LAUREL CANYON BLVD',
#  '1315 FAIR OAKS AVE',
#  '10150 STONEHURST AVE',
#  '100 TERRANEA WAY # F',
#  '446 S MARKET ST',
#  '18663 VENTURA BLVD STE 100',
#  '514 W TORRANCE BLVD',
#  '7351 ROSECRANS AVE STE F',
#  '2908 MAIN ST',
#  '4941 E FLORENCE AVE',
#  '3403 W SLAUSON AVE',
#  '210 N AVIATION BLVD UNIT C',
#  '3272 SLAUSON AVE',
#  '3377 WILSHIRE BLVD # 112',
#  '3511 PACIFIC COAST HWY STE G',
#  '140 N LA BREA AVE',
#  '118 ENTRADA DR',
#  '1217 CYPRESS AVE',
#  '324 S AZUSA AVE',
#  '400 S BALDWIN AVE STE 440',
#  '13745 PARAMOUNT BLVD',
#  '3620 S NOGALES ST',
#  '1938 W 3RD ST',
#  '111 S PACIFIC AVE',
#  '600 S MAIN ST',
#  '11210 GLENOAKS BLVD',
#  '1145 W ARTESIA BLVD',
#  '161 N GLENDORA AVE',
#  '1201 S FIGUEROA ST',
#  '7540 EASTERN AVE',
#  '2216 SEPULVEDA BLVD',
#  '4715 W ADAMS BLVD',
#  '4151 PROSPECT AVE',
#  '17338 W SUNSET BLVD',
#  '6650 N IRWINDALE AVE',
#  '3822 N PECK RD',
#  '6504 HOLLYWOOD BLVD',
#  '9159 RESEDA BLVD',
#  '2838 ROWENA AVE',
#  '1703 W MAIN ST',
#  '1002 MONTANA AVE',
#  '18755 COLIMA RD',
#  '505 W FLORENCE AVE',
#  '3450 W 6TH ST # 108',
#  '1245 N AVALON BLVD',
#  '10801 HAWTHORNE BLVD',
#  '1131 S GLENDORA AVE',
#  '1457 E FLORENCE AVE STE 112',
#  '6800 RESEDA BLVD #H',
#  '6333 W 3RD ST STE# 175-E',
#  '7607 WHITE OAK AVE',
#  '13532 LAKEWOOD BLVD',
#  '11255 183RD ST',
#  '300 WORLD WAY',
#  '831 N HACIENDA BLVD',
#  '1608 W WASHINGTON BLVD',
#  '4059 W 3RD ST',
#  '8875 GLENOAKS BLVD',
#  '3600 ROSEMEAD BLVD',
#  '3819 W SUNSET BLVD',
#  '18412 PACIFIC COAST HWY',
#  '3911 S FIGUEROA ST',
#  '17018 DEVONSHIRE ST # #7142',
#  '10595 PICO BLVD',
#  '1800 E ROSECRANS AVE',
#  '1301 MANHATTAN AVE',
#  '7045 E SOMERSET BLVD',
#  '5990 GREEN VALLEY CIR',
#  '15810 S CRENSHAW BLVD',
#  '14650 ROSCOE BLVD STE 4',
#  ...]

# %%
# Business Match Parameters to get Yelp ID 
url_bm = 'https://api.yelp.com/v3/businesses/matches'

parameters_bm = {\
                 'name': address.iloc[1,1],\
                 'address1' : address.iloc[1,2],\
                 'city': address.iloc[1,3],\
                 'state': 'CA',\
                 'country': 'US'
             }

# %%
# Use Requests.get and convert to JSON from Yelp Business Match Endpoint
r_bm = requests.get(url = url_bm, params = parameters_bm, headers = headers)
json_data_bm = r_bm.json()

# %%
json_data_bm
# Out:
# {'businesses': [{'id': 'U8Gfec-186rQ93-3jbLdCQ',
#    'alias': 'dennys-la-puente',
#    'name': "Denny's",
#    'coordinates': {'latitude': 34.0207864, 'longitude': -117.9586692},
#    'location': {'address1': '15553 Valley Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'La Puente',
#     'zip_code': '91744',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['15553 Valley Blvd', 'La Puente, CA 91744']},
#    'phone': '+16269683930',
#    'display_phone': '(626) 968-3930'}]}

# %%
json_data_bm['businesses']
# Out:
# [{'id': 'U8Gfec-186rQ93-3jbLdCQ',
#   'alias': 'dennys-la-puente',
#   'name': "Denny's",
#   'coordinates': {'latitude': 34.0207864, 'longitude': -117.9586692},
#   'location': {'address1': '15553 Valley Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'La Puente',
#    'zip_code': '91744',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['15553 Valley Blvd', 'La Puente, CA 91744']},
#   'phone': '+16269683930',
#   'display_phone': '(626) 968-3930'}]

# %%
# Extract Yelp ID and append yelp ID to addresses
ans_bm = json_data_bm['businesses'][0]
yelp_id = ans_bm.get('id')

# %%
#Business Details Parameters to get rating, review count, price, categories, latitude, and longitude
url_bd = 'https://api.yelp.com/v3/businesses/{}'.format(yelp_id)

# %%
# Request from Yelp Business Details Endpoint
r_bd = requests.get(url = url_bd, headers = headers)
json_data_bd = r_bd.json()

# %%
json_data_bm['businesses'] == []
# Out:
# True

# %%
# Business Details Output
answer = json_data_bd
categories = [sub['title'] for sub in answer.get('categories')]
output = {
    'name': answer.get('name'),
    'address': ', '.join([str(elem)for elem in answer.get('location').get('display_address')]),
    'review_count': answer.get('review_count'),
    'rating' : answer.get('rating'),
    'price': answer.get('price'),
    'categories': ', '.join([str(elem) for elem in [sub['title'] for sub in answer.get('categories')]]),
    'latitude': answer.get('coordinates').get('latitude'),
    'longitude': answer.get('coordinates').get('longitude'),
    'yelp_id': answer.get('id'),
    'hours': answer.get('hours')[0].get('hours_type')
    
}

# %%
output
# Out:
# {'name': "Denny's",
#  'address': '15553 Valley Blvd, La Puente, CA 91744',
#  'review_count': 92,
#  'rating': 2.5,
#  'price': '$',
#  'categories': 'Diners, Breakfast & Brunch, American (Traditional)',
#  'latitude': 34.0207864,
#  'longitude': -117.9586692,
#  'yelp_id': 'U8Gfec-186rQ93-3jbLdCQ',
#  'hours': 'REGULAR'}
