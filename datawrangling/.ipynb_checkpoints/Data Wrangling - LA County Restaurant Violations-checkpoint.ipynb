# %% [markdown]
# ## Import Necessary Packages

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime as dt
from datetime import datetime
import seaborn as sns
import os

# %% [markdown]
# ## Extract Data

# %%
inspections = pd.read_csv('../rawdata/inspections.csv')
violations = pd.read_csv('../rawdata/violations.csv')

# %% [markdown]
# ## Data Exploration

# %%
inspections.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 386336 entries, 0 to 386335
# Data columns (total 19 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ACTIVITY DATE         386336 non-null  object
#  1   OWNER ID              386336 non-null  object
#  2   OWNER NAME            386336 non-null  object
#  3   FACILITY ID           386336 non-null  object
#  4   FACILITY NAME         386336 non-null  object
#  5   RECORD ID             386336 non-null  object
#  6   PROGRAM NAME          386336 non-null  object
#  7   PROGRAM STATUS        386336 non-null  object
#  8   PROGRAM ELEMENT (PE)  386336 non-null  int64
#  9   PE DESCRIPTION        386336 non-null  object
#  10  FACILITY ADDRESS      386336 non-null  object
#  11  FACILITY CITY         386336 non-null  object
#  12  FACILITY STATE        386336 non-null  object
#  13  FACILITY ZIP          386336 non-null  int64
#  14  SERVICE CODE          386336 non-null  int64
#  15  SERVICE DESCRIPTION   386336 non-null  object
#  16  SCORE                 386336 non-null  int64
#  17  SERIAL NUMBER         386336 non-null  object
#  18  EMPLOYEE ID           386336 non-null  object
# dtypes: int64(4), object(15)
# memory usage: 56.0+ MB

# %%
violations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   SERIAL NUMBER          1048575 non-null  object
#  1   VIOLATION  STATUS      1048575 non-null  object
#  2   VIOLATION CODE         1048575 non-null  object
#  3   VIOLATION DESCRIPTION  1048575 non-null  object
#  4   POINTS                 1048575 non-null  float64
# dtypes: float64(1), object(4)
# memory usage: 40.0+ MB

# %%
inspections.columns = inspections.columns.str.lower()
inspections.columns = inspections.columns.str.replace(' ','_')
violations.columns = violations.columns.str.lower()
violations.columns = violations.columns.str.replace(' ','_')

# %%
inspections.score.max(), inspections.score.min()
# Out:
# (100, 3)

# %%
violations.points.max(), violations.points.min()
# Out:
# (11.0, 0.0)

# %% [markdown]
# * Inspections Score MAX value shows us there are some restaurants that got perfect scores

# %%
inspections['serial_number'].nunique(),violations['serial_number'].nunique()
# Out:
# (386336, 224009)

# %%
merged_df = pd.merge(inspections, violations, how = 'left', on = 'serial_number')

# %%
merged_df.head()
# Out:
#   activity_date   owner_id        owner_name facility_id   facility_name  \
# 0    11/10/2015  OW0126532  GEN TORRANCE LLC   FA0162834  GEN KOREAN BBQ
# 1    11/10/2015  OW0126532  GEN TORRANCE LLC   FA0162834  GEN KOREAN BBQ
# 2    11/10/2015  OW0126532  GEN TORRANCE LLC   FA0162834  GEN KOREAN BBQ
# 3    11/10/2015  OW0126532  GEN TORRANCE LLC   FA0162834  GEN KOREAN BBQ
# 4    11/10/2015  OW0126532  GEN TORRANCE LLC   FA0162834  GEN KOREAN BBQ
#
#    record_id    program_name program_status  program_element_(pe)  \
# 0  PR0150985  GEN KOREAN BBQ         ACTIVE                  1638
# 1  PR0150985  GEN KOREAN BBQ         ACTIVE                  1638
# 2  PR0150985  GEN KOREAN BBQ         ACTIVE                  1638
# 3  PR0150985  GEN KOREAN BBQ         ACTIVE                  1638
# 4  PR0150985  GEN KOREAN BBQ         ACTIVE                  1638
#
#                         pe_description  ... facility_zip service_code  \
# 0  RESTAURANT (61-150) SEATS HIGH RISK  ...        90505            1
# 1  RESTAURANT (61-150) SEATS HIGH RISK  ...        90505            1
# 2  RESTAURANT (61-150) SEATS HIGH RISK  ...        90505            1
# 3  RESTAURANT (61-150) SEATS HIGH RISK  ...        90505            1
# 4  RESTAURANT (61-150) SEATS HIGH RISK  ...        90505            1
#
#   service_description  score  serial_number employee_id  violation__status  \
# 0  ROUTINE INSPECTION     93      DA0EU4KUG   EE0000306  OUT OF COMPLIANCE
# 1  ROUTINE INSPECTION     93      DA0EU4KUG   EE0000306  OUT OF COMPLIANCE
# 2  ROUTINE INSPECTION     93      DA0EU4KUG   EE0000306  OUT OF COMPLIANCE
# 3  ROUTINE INSPECTION     93      DA0EU4KUG   EE0000306  OUT OF COMPLIANCE
# 4  ROUTINE INSPECTION     93      DA0EU4KUG   EE0000306  OUT OF COMPLIANCE
#
#   violation_code                              violation_description points
# 0           F027                 # 27. Food separated and protected    1.0
# 1           F037  # 37. Adequate ventilation and lighting; desig...    1.0
# 2           F040  # 40. Plumbing: Plumbing in good repair, prope...    1.0
# 3           F006  # 06. Adequate handwashing facilities supplied...    2.0
# 4           F036  # 36. Equipment, utensils and linens: storage ...    1.0
#
# [5 rows x 23 columns]

# %%
merged_df['activity_date'] = pd.to_datetime(merged_df['activity_date'])
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1210653 entries, 0 to 1210652
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   activity_date          1210653 non-null  datetime64[ns]
#  1   owner_id               1210653 non-null  object
#  2   owner_name             1210653 non-null  object
#  3   facility_id            1210653 non-null  object
#  4   facility_name          1210653 non-null  object
#  5   record_id              1210653 non-null  object
#  6   program_name           1210653 non-null  object
#  7   program_status         1210653 non-null  object
#  8   program_element_(pe)   1210653 non-null  int64
#  9   pe_description         1210653 non-null  object
#  10  facility_address       1210653 non-null  object
#  11  facility_city          1210653 non-null  object
#  12  facility_state         1210653 non-null  object
#  13  facility_zip           1210653 non-null  int64
#  14  service_code           1210653 non-null  int64
#  15  service_description    1210653 non-null  object
#  16  score                  1210653 non-null  int64
#  17  serial_number          1210653 non-null  object
#  18  employee_id            1210653 non-null  object
#  19  violation__status      1048238 non-null  object
#  20  violation_code         1048238 non-null  object
#  21  violation_description  1048238 non-null  object
#  22  points                 1048238 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(4), object(17)
# memory usage: 221.7+ MB

# %% [markdown]
# ### Understanding the Scoring
# * Points column is the number of points taken for the violation.
# * Score is the overall inpsection score out of 100.
# ---
# * Information from LA County Food Inspection Reference Guide:
# __[Inspection Guide](http://www.publichealth.lacounty.gov/eh/docs/RefGuideFoodInspectionReport.pdf)__
#
# >* Major Violation results in 4 pt Deduction
# >* Two Major Violations result in additional 3pt deduction and possible closure
# >* Permit suspension due to vermin infestation, no water, or now sewage available, additional 7pt deduction for each closure type
# >* Minor Violation result in 2pt deduction
# >* Good Retail Practicies (Low Risk Violations), result in 1 pt violation

# %% [markdown]
# ### Additional Notes
#
# * Serial Number is unique ID for each inspection
# * Record ID is a UNIQUE ID number for each health program at a facility. A facility can have multiple programs!
# * Program name is a unique name for each program

# %% [markdown]
# * Now restaurants that got perfect scores are included in the merged data frame --> look at null values in violation_status, violation_code, violation_description, and points
# * Split the program elements part!
# * Analyze by program elements broken down
# * Break down the date time by year --> analyze by year
# * Analyze by month!

# %% [markdown]
# * Now inspect score and number of inspections by year and month
# * First remove duplicates --> serial numbers change with each inspection --> remove duplicates for that to get the accurate count and distribution for scores

# %%
merged_df['year'] = merged_df['activity_date'].dt.year
merged_df['month'] = merged_df['activity_date'].dt.month
merged_df['day'] = merged_df['activity_date'].dt.day
merged_df['quarter'] = merged_df['activity_date'].dt.quarter
merged_df.head()
# Out:
#   activity_date   owner_id        owner_name facility_id   facility_name  \
# 0    2015-11-10  OW0126532  GEN TORRANCE LLC   FA0162834  GEN KOREAN BBQ
# 1    2015-11-10  OW0126532  GEN TORRANCE LLC   FA0162834  GEN KOREAN BBQ
# 2    2015-11-10  OW0126532  GEN TORRANCE LLC   FA0162834  GEN KOREAN BBQ
# 3    2015-11-10  OW0126532  GEN TORRANCE LLC   FA0162834  GEN KOREAN BBQ
# 4    2015-11-10  OW0126532  GEN TORRANCE LLC   FA0162834  GEN KOREAN BBQ
#
#    record_id    program_name program_status  program_element_(pe)  \
# 0  PR0150985  GEN KOREAN BBQ         ACTIVE                  1638
# 1  PR0150985  GEN KOREAN BBQ         ACTIVE                  1638
# 2  PR0150985  GEN KOREAN BBQ         ACTIVE                  1638
# 3  PR0150985  GEN KOREAN BBQ         ACTIVE                  1638
# 4  PR0150985  GEN KOREAN BBQ         ACTIVE                  1638
#
#                         pe_description  ... serial_number employee_id  \
# 0  RESTAURANT (61-150) SEATS HIGH RISK  ...     DA0EU4KUG   EE0000306
# 1  RESTAURANT (61-150) SEATS HIGH RISK  ...     DA0EU4KUG   EE0000306
# 2  RESTAURANT (61-150) SEATS HIGH RISK  ...     DA0EU4KUG   EE0000306
# 3  RESTAURANT (61-150) SEATS HIGH RISK  ...     DA0EU4KUG   EE0000306
# 4  RESTAURANT (61-150) SEATS HIGH RISK  ...     DA0EU4KUG   EE0000306
#
#    violation__status  violation_code  \
# 0  OUT OF COMPLIANCE            F027
# 1  OUT OF COMPLIANCE            F037
# 2  OUT OF COMPLIANCE            F040
# 3  OUT OF COMPLIANCE            F006
# 4  OUT OF COMPLIANCE            F036
#
#                                violation_description points  year month day  \
# 0                 # 27. Food separated and protected    1.0  2015    11  10
# 1  # 37. Adequate ventilation and lighting; desig...    1.0  2015    11  10
# 2  # 40. Plumbing: Plumbing in good repair, prope...    1.0  2015    11  10
# 3  # 06. Adequate handwashing facilities supplied...    2.0  2015    11  10
# 4  # 36. Equipment, utensils and linens: storage ...    1.0  2015    11  10
#
#   quarter
# 0       4
# 1       4
# 2       4
# 3       4
# 4       4
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Categorize Violations as Major, Minor, Critical using Points and Violation Code

# %% [markdown]
# Match point value with violation codes based on the reference book above.
# * Critical -> 11 pts deduction
# * Major --> 4 pts deduction
# * Minor --> 2 pts deduction
# * Retail Practices --> 1 pt deduction
# * Double Major --> 3pt reduction
# * NaN for all that don't match conditions

# %%
merged_df['points'].value_counts(dropna = False)
# Out:
# 1.0     792962
# 2.0     187705
# NaN     162415
# 4.0      48694
# 0.0      14366
# 3.0       2324
# 11.0      2187
# Name: points, dtype: int64

# %%
zero = merged_df[merged_df['points'] == 0.0]
zero[zero['violation_code']=='F021']
# Out:
#         activity_date   owner_id                       owner_name facility_id  \
# 205819     2016-06-07  OW0030630                        ROMAN INC   FA0037751
# 289189     2017-01-19  OW0022348               LOVE SUSHI II INC.   FA0036104
# 334406     2017-03-09  OW0226883                  MARICELA MEDINA   FA0221954
# 346355     2017-03-20  OW0035201           TECHAWUTIWAT, TANAPORN   FA0065827
# 349721     2017-03-23  OW0008418            COBAR, RENE GUILLERMO   FA0002904
# 351492     2017-02-21  OW0186096                GREGORIA ESCARENO   FA0180753
# 356004     2017-02-27  OW0178492         ALEJANDRO GERECERO ORTIZ   FA0171405
# 357453     2017-04-04  OW0015476             HI WORLD CORPORATION   FA0038760
# 361713     2017-02-23  OW0185252              LAURA VILLAVICENCIO   FA0179759
# 363052     2017-02-23  OW0186222              TAQUERIA LOS SANTOS   FA0180884
# 379419     2017-02-28  OW0010503                   DUNK, MILTON F   FA0047938
# 380920     2017-03-23  OW0004816               BLAZIN WINGS, INC.   FA0011178
# 400064     2017-06-05  OW0185377              TOUCH OF AEGEAN LLC   FA0179897
# 443110     2017-08-29  OW0002105                     ALFARO, JUAN   FA0066217
# 453859     2017-08-30  OW0031717     SANTA MONICA SPEEDWAY CARWAS   FA0005933
# 459449     2017-07-28  OW0104987         ORTIZ, HERMILA J ESPARZA   FA0141829
# 464943     2017-07-25  OW0104688               SODEXO AMERICA LLC   FA0141556
# 466056     2017-08-23  OW0030228                      RIVAS, ROSA   FA0065160
# 475156     2017-09-18  OW0029458           RALPHS GROCERY COMPANY   FA0045210
# 483176     2017-08-07  OW0101472                VELASQUEZ, SANDRA   FA0138066
# 513402     2017-12-13  OW0242797       HANJIN INTERNATIONAL CORP.   FA0248372
# 517534     2017-11-08  OW0226837           MARYMOUNT SCHOOL, CORP   FA0221862
# 521366     2017-12-11  OW0010177                      DO, TIN DUC   FA0138340
# 530559     2017-10-24  OW0106251              SARKISIAN SARKIS S.   FA0143111
# 534549     2017-12-15  OW0012043                  FLORES, ELPIDIO   FA0013817
# 557945     2018-03-06  OW0026858                ORBIS TERTIUS INC   FA0070672
# 564189     2018-01-04  OW0006203        CARMELA ICE CREAM COMPANY   FA0203843
# 572843     2018-02-06  OW0183509                      JORGE SORTO   FA0225942
# 615100     2018-05-01  OW0010578                 E & T FOODS INC.   FA0007994
# 618233     2018-03-20  OW0124519                       ATEF NAEEM   FA0159506
# 680944     2018-06-19  OW0029409                      RAHIM ABDUR   FA0046053
# 681550     2018-06-18  OW0128246                        JCJM, LLC   FA0164947
# 738602     2018-09-13  OW0183523                         JOYT INC   FA0177610
# 750199     2018-08-24  OW0254750                     1001 ARTESIA   FA0263425
# 782269     2018-11-08  OW0033830                    SPROUTS, INC.   FA0251854
# 842686     2019-03-14  OW0243589                PAN VICTORIA INC.   FA0249317
# 845015     2019-02-06  OW0003909               BAR LUBITSCH, INC.   FA0058005
# 936356     2019-08-01  OW0236005                   ARMAN GALSTYAN   FA0239784
# 955404     2019-07-02  OW0026694           OLIVA HERNANDEZ, JORGE   FA0002751
# 981267     2019-07-09  OW0001675              ACJ ENTERPRISES INC   FA0141982
# 983568     2019-06-04  OW0033351             SODEXO AMERICA, LLC.   FA0012664
# 993597     2019-08-21  OW0002045                    ALCORTA, LUPE   FA0061647
# 1013808    2019-09-03  OW0254556  HAO JINK SEAFOOD RESTAURANT INC   FA0263196
# 1059286    2019-12-17  OW0028749                  PNS STORES, INC   FA0058367
# 1087624    2019-10-25  OW0123028                   KAIS GROUP INC   FA0157906
# 1126671    2020-01-22  OW0260006                DDR PARTNERS INC.   FA0269892
# 1196172    2020-08-17  OW0012029                FLORES, FRANCISCO   FA0038063
#
#                                  facility_name  record_id  \
# 205819                     MARISCOS SAN ISIDRO  PR0001060
# 289189                              LOVE SUSHI  PR0021087
# 334406                        LITO'S CORK ROOM  PR0176941
# 346355             LITTLE JASMINE THAI CUISINE  PR0017693
# 349721                           ADDY'S BAKERY  PR0017304
# 351492                             EL MARATIAL  PR0174555
# 356004                         EL PESCADOR #11  PR0161474
# 357453                   TSUJITA LA RESTAURANT  PR0031994
# 361713                   LA MONARCA MICHOACANA  PR0173419
# 363052                     TAQUERIA LOS SANTOS  PR0174716
# 379419                               SLAM DUNK  PR0030029
# 380920                      BUFFALO WILD WINGS  PR0026931
# 400064                               NUKA CAFE  PR0173579
# 443110                     MAGGIES COFFEE SHOP  PR0010451
# 453859                       BLUEWAVE CAR WASH  PR0042553
# 459449             LA FORTALAZA OF LOS ANGELES  PR0127698
# 464943                      SODEXO AMERICA LLC  PR0127280
# 466056                        LA FLOR DE IZOTE  PR0000741
# 475156                      RALPHS MARKET #269  PR0002732
# 483176                        PANADERIA CHANNY  PR0122301
# 513402   INTERCONTINENTAL LOS ANGELES DOWNTOWN  PR0198391
# 517534   MARY MOUNT HIGH SCHOOL - KITCHEN PREP  PR0176850
# 521366               WATER GOURMET & JUICE BAR  PR0122628
# 530559                TRIMANA GRILL IRW INDALE  PR0128222
# 534549                  FLORES DISCOUNT MARKET  PR0007247
# 557945                       SOLAR DE CAHUENGA  PR0035708
# 564189                       CARMELA ICE CREAM  PR0176246
# 572843                     LA BAMBA RESTAURANT  PR0181261
# 615100            BAJA RANCH SUPERMARKET-DEFBK  PR0034784
# 618233                    A & M TOBACCO MARKET  PR0147569
# 680944                 ROBINA'S INDIAN CUISINE  PR0033781
# 681550               JERSEY MIKE'S SUBS #20153  PR0153241
# 738602                     DON RAMIREZ  LIQUOR  PR0170644
# 750199                            1001 ARTESIA  PR0214339
# 782269                  SPROUTS FARMERS MARKET  PR0209143
# 842686                       PAN VICTORIA INC.  PR0198046
# 845015                            BAR LUBITSCH  PR0004760
# 936356                   MEDITERRANEAN DELIGHT  PR0187775
# 955404                           AAA JUICE BAR  PR0045167
# 981267            PANADERIA & PASTELERIA ELPAV  PR0127065
# 983568                             CAMPUS CAFE  PR0035051
# 993597                             EL TEJANITO  PR0012071
# 1013808              CHINA MANDARIN RESTAURANT  PR0214043
# 1059286                         BIG LOTS #4128  PR0034974
# 1087624              PING PONG CHINESE CUISINE  PR0146004
# 1126671           MANHATTAN BEACH COUNTRY CLUB  PR0222591
# 1196172            MARY'S BIONI COS Y RASPADOS  PR0026904
#
#                                               program_name program_status  \
# 205819                                 MARISCOS SAN ISIDRO         ACTIVE
# 289189                                          LOVE SUSHI         ACTIVE
# 334406                                    LITO'S CORK ROOM         ACTIVE
# 346355                         LITTLE JASMINE THAI CUISINE       INACTIVE
# 349721                                       ADDY'S BAKERY       INACTIVE
# 351492                                        EL MANANTIAL       INACTIVE
# 356004                                     EL PESCADOR #11       INACTIVE
# 357453                               TSUJITA LA RESTAURANT         ACTIVE
# 361713                               LA MONARCA MICHOACANA         ACTIVE
# 363052                                 TAQUERIA LOS SANTOS         ACTIVE
# 379419                                           SLAM DUNK         ACTIVE
# 380920                                  BUFFALO WILD WINGS         ACTIVE
# 400064                                           NUKA CAFE         ACTIVE
# 443110                                 MAGGIES COFFEE SHOP         ACTIVE
# 453859                                   BLUEWAVE CAR WASH         ACTIVE
# 459449                         LA FORTALAZA OF LOS ANGELES         ACTIVE
# 464943                                  SODEXO AMERICA LLC         ACTIVE
# 466056                                    LA FLOR DE IZOTE       INACTIVE
# 475156                                 RALPHS GROCERY #269         ACTIVE
# 483176                                    PANADERIA CHANNY         ACTIVE
# 513402   INTERCONTINENTAL LOS ANGELES DOWNTOWN - DEKKAD...         ACTIVE
# 517534               MARY MOUNT HIGH SCHOOL - KITCHEN PREP         ACTIVE
# 521366                           WATER GOURMET & JUICE BAR       INACTIVE
# 530559                            TRIMANA GRILL IRW INDALE         ACTIVE
# 534549                              FLORES DISCOUNT MARKET         ACTIVE
# 557945                                   SOLAR DE CAHUENGA       INACTIVE
# 564189                                   CARMELA ICE CREAM       INACTIVE
# 572843                                 LA BAMBA RESTAURANT       INACTIVE
# 615100                         BAJA RANCH SUPERMARKET-MEAT         ACTIVE
# 618233                                A & M TOBACCO MARKET         ACTIVE
# 680944                             ROBINA'S INDIAN CUISINE         ACTIVE
# 681550                           JERSEY MIKE'S SUBS #20153         ACTIVE
# 738602                                 DON RAMIREZ  LIQUOR         ACTIVE
# 750199                                        1001 ARTESIA         ACTIVE
# 782269                  SPROUTS FARMERS MARKET - MEAT DEPT         ACTIVE
# 842686                                   PAN VICTORIA INC.         ACTIVE
# 845015                                        BAR LUBITSCH         ACTIVE
# 936356                               MEDITERRANEAN DELIGHT       INACTIVE
# 955404                                       AAA JUICE BAR         ACTIVE
# 981267                        PANADERIA & PASTELERIA ELPAV         ACTIVE
# 983568                                         CAMPUS CAFE         ACTIVE
# 993597                                         EL TEJANITO         ACTIVE
# 1013808                          CHINA MANDARIN RESTAURANT         ACTIVE
# 1059286                                     BIG LOTS #4128         ACTIVE
# 1087624                          PING PONG CHINESE CUISINE       INACTIVE
# 1126671          MANHATTAN BEACH COUNTRY CLUB - RESTAURANT         ACTIVE
# 1196172                        MARY'S BIONI COS Y RASPADOS         ACTIVE
#
#          program_element_(pe)                              pe_description  \
# 205819                   1638         RESTAURANT (61-150) SEATS HIGH RISK
# 289189                   1632           RESTAURANT (0-30) SEATS HIGH RISK
# 334406                   1633           RESTAURANT (31-60) SEATS LOW RISK
# 346355                   1632           RESTAURANT (0-30) SEATS HIGH RISK
# 349721                   1631       RESTAURANT (0-30) SEATS MODERATE RISK
# 351492                   1631       RESTAURANT (0-30) SEATS MODERATE RISK
# 356004                   1638         RESTAURANT (61-150) SEATS HIGH RISK
# 357453                   1632           RESTAURANT (0-30) SEATS HIGH RISK
# 361713                   1631       RESTAURANT (0-30) SEATS MODERATE RISK
# 363052                   1632           RESTAURANT (0-30) SEATS HIGH RISK
# 379419                   1636          RESTAURANT (61-150) SEATS LOW RISK
# 380920                   1641         RESTAURANT (151 + ) SEATS HIGH RISK
# 400064                   1632           RESTAURANT (0-30) SEATS HIGH RISK
# 443110                   1632           RESTAURANT (0-30) SEATS HIGH RISK
# 453859                   1610       FOOD MKT RETAIL (1-1,999 SF) LOW RISK
# 459449                   1610       FOOD MKT RETAIL (1-1,999 SF) LOW RISK
# 464943                   1641         RESTAURANT (151 + ) SEATS HIGH RISK
# 466056                   1635          RESTAURANT (31-60) SEATS HIGH RISK
# 475156                   1614   FOOD MKT RETAIL (2,000+ SF) MODERATE RISK
# 483176                   1632           RESTAURANT (0-30) SEATS HIGH RISK
# 513402                   1641         RESTAURANT (151 + ) SEATS HIGH RISK
# 517534                   1632                    PRIVATE SCHOOL CAFETERIA
# 521366                   1631       RESTAURANT (0-30) SEATS MODERATE RISK
# 530559                   1638         RESTAURANT (61-150) SEATS HIGH RISK
# 534549                   1611  FOOD MKT RETAIL (1-1,999 SF) MODERATE RISK
# 557945                   1635          RESTAURANT (31-60) SEATS HIGH RISK
# 564189                   1631       RESTAURANT (0-30) SEATS MODERATE RISK
# 572843                   1635          RESTAURANT (31-60) SEATS HIGH RISK
# 615100                   1612      FOOD MKT RETAIL (1-1,999 SF) HIGH RISK
# 618233                   1610       FOOD MKT RETAIL (1-1,999 SF) LOW RISK
# 680944                   1632           RESTAURANT (0-30) SEATS HIGH RISK
# 681550                   1631       RESTAURANT (0-30) SEATS MODERATE RISK
# 738602                   1610       FOOD MKT RETAIL (1-1,999 SF) LOW RISK
# 750199                   1614   FOOD MKT RETAIL (2,000+ SF) MODERATE RISK
# 782269                   1612      FOOD MKT RETAIL (1-1,999 SF) HIGH RISK
# 842686                   1632           RESTAURANT (0-30) SEATS HIGH RISK
# 845015                   1633           RESTAURANT (31-60) SEATS LOW RISK
# 936356                   1632           RESTAURANT (0-30) SEATS HIGH RISK
# 955404                   1631       RESTAURANT (0-30) SEATS MODERATE RISK
# 981267                   1632           RESTAURANT (0-30) SEATS HIGH RISK
# 983568                   1638         RESTAURANT (61-150) SEATS HIGH RISK
# 993597                   1635          RESTAURANT (31-60) SEATS HIGH RISK
# 1013808                  1638         RESTAURANT (61-150) SEATS HIGH RISK
# 1059286                  1610       FOOD MKT RETAIL (1-1,999 SF) LOW RISK
# 1087624                  1638         RESTAURANT (61-150) SEATS HIGH RISK
# 1126671                  1641         RESTAURANT (151 + ) SEATS HIGH RISK
# 1196172                  1631       RESTAURANT (0-30) SEATS MODERATE RISK
#
#          ... serial_number employee_id  violation__status  violation_code  \
# 205819   ...     DAH5EMEOW   EE0000592  OUT OF COMPLIANCE            F021
# 289189   ...     DAEZVGAFY   EE0000364  OUT OF COMPLIANCE            F021
# 334406   ...     DA0801180   EE0000081  OUT OF COMPLIANCE            F021
# 346355   ...     DAMPBDTVI   EE0000067  OUT OF COMPLIANCE            F021
# 349721   ...     DAMHQ7JGY   EE0001009  OUT OF COMPLIANCE            F021
# 351492   ...     DALFSRGXD   EE0000691  OUT OF COMPLIANCE            F021
# 356004   ...     DA110CDDI   EE0000145  OUT OF COMPLIANCE            F021
# 357453   ...     DAEVNWEA5   EE0000684  OUT OF COMPLIANCE            F021
# 361713   ...     DA7KIJ0E0   EE0000691  OUT OF COMPLIANCE            F021
# 363052   ...     DAINGOISX   EE0000113  OUT OF COMPLIANCE            F021
# 379419   ...     DAAK1FP0Z   EE0000113  OUT OF COMPLIANCE            F021
# 380920   ...     DAMVY3QAP   EE0000067  OUT OF COMPLIANCE            F021
# 400064   ...     DAAUKZDXL   EE0000924  OUT OF COMPLIANCE            F021
# 443110   ...     DA3K5N2SE   EE0000691  OUT OF COMPLIANCE            F021
# 453859   ...     DA4M5XTPQ   EE0000924  OUT OF COMPLIANCE            F021
# 459449   ...     DAG1EUUWX   EE0000255  OUT OF COMPLIANCE            F021
# 464943   ...     DA0I0H2HG   EE0000495  OUT OF COMPLIANCE            F021
# 466056   ...     DAEYVHJGI   EE0000691  OUT OF COMPLIANCE            F021
# 475156   ...     DAAZIJLOY   EE0000996  OUT OF COMPLIANCE            F021
# 483176   ...     DAA7PVWCD   EE0000996  OUT OF COMPLIANCE            F021
# 513402   ...     DAFO067PD   EE0000905  OUT OF COMPLIANCE            F021
# 517534   ...     DA0988001   EE0000684  OUT OF COMPLIANCE            F021
# 521366   ...     DA3DNKL02   EE0000375  OUT OF COMPLIANCE            F021
# 530559   ...     DAKOQIQVI   EE0000495  OUT OF COMPLIANCE            F021
# 534549   ...     DAM04QH0M   EE0000691  OUT OF COMPLIANCE            F021
# 557945   ...     DAC0IB8B0   EE0000709  OUT OF COMPLIANCE            F021
# 564189   ...     DAIFXGQNS   EE0000605  OUT OF COMPLIANCE            F021
# 572843   ...     DAAPVPKXS   EE0000464  OUT OF COMPLIANCE            F021
# 615100   ...     DA90MLXMG   EE0000842  OUT OF COMPLIANCE            F021
# 618233   ...     DA001VEBD   EE0000958  OUT OF COMPLIANCE            F021
# 680944   ...     DAGOYDXQR   EE0000451  OUT OF COMPLIANCE            F021
# 681550   ...     DACJHYWUV   EE0000699  OUT OF COMPLIANCE            F021
# 738602   ...     DAFJ8XLMY   EE0000382  OUT OF COMPLIANCE            F021
# 750199   ...     DADVAA3RU   EE0000873  OUT OF COMPLIANCE            F021
# 782269   ...     DABWUB4Q5   EE0000145  OUT OF COMPLIANCE            F021
# 842686   ...     DA0TWCVEL   EE0001120  OUT OF COMPLIANCE            F021
# 845015   ...     DAHHGZM0R   EE0000873  OUT OF COMPLIANCE            F021
# 936356   ...     DAEHVFW4S   EE0000630  OUT OF COMPLIANCE            F021
# 955404   ...     DA2DHOG06   EE0000872  OUT OF COMPLIANCE            F021
# 981267   ...     DAFD0FZX2   EE0000255  OUT OF COMPLIANCE            F021
# 983568   ...     DABKAHXK0   EE0000495  OUT OF COMPLIANCE            F021
# 993597   ...     DACDIM0Z8   EE0001151  OUT OF COMPLIANCE            F021
# 1013808  ...     DABGZACAW   EE0000182  OUT OF COMPLIANCE            F021
# 1059286  ...     DAJJCOWC8   EE0000045  OUT OF COMPLIANCE            F021
# 1087624  ...     DAGW0HG46   EE0000605  OUT OF COMPLIANCE            F021
# 1126671  ...     DAH0X19W6   EE0001074  OUT OF COMPLIANCE            F021
# 1196172  ...     DA2WFZJNK   EE0000249  OUT OF COMPLIANCE            F021
#
#           violation_description points  year month day quarter
# 205819   # 21b. Water available    0.0  2016     6   7       2
# 289189   # 21b. Water available    0.0  2017     1  19       1
# 334406   # 21b. Water available    0.0  2017     3   9       1
# 346355   # 21b. Water available    0.0  2017     3  20       1
# 349721   # 21b. Water available    0.0  2017     3  23       1
# 351492   # 21b. Water available    0.0  2017     2  21       1
# 356004   # 21b. Water available    0.0  2017     2  27       1
# 357453   # 21b. Water available    0.0  2017     4   4       2
# 361713   # 21b. Water available    0.0  2017     2  23       1
# 363052   # 21b. Water available    0.0  2017     2  23       1
# 379419   # 21b. Water available    0.0  2017     2  28       1
# 380920   # 21b. Water available    0.0  2017     3  23       1
# 400064   # 21b. Water available    0.0  2017     6   5       2
# 443110   # 21b. Water available    0.0  2017     8  29       3
# 453859   # 21b. Water available    0.0  2017     8  30       3
# 459449   # 21b. Water available    0.0  2017     7  28       3
# 464943   # 21b. Water available    0.0  2017     7  25       3
# 466056   # 21b. Water available    0.0  2017     8  23       3
# 475156   # 21b. Water available    0.0  2017     9  18       3
# 483176   # 21b. Water available    0.0  2017     8   7       3
# 513402   # 21b. Water available    0.0  2017    12  13       4
# 517534   # 21b. Water available    0.0  2017    11   8       4
# 521366   # 21b. Water available    0.0  2017    12  11       4
# 530559   # 21b. Water available    0.0  2017    10  24       4
# 534549   # 21b. Water available    0.0  2017    12  15       4
# 557945   # 21b. Water available    0.0  2018     3   6       1
# 564189   # 21b. Water available    0.0  2018     1   4       1
# 572843   # 21b. Water available    0.0  2018     2   6       1
# 615100   # 21b. Water available    0.0  2018     5   1       2
# 618233   # 21b. Water available    0.0  2018     3  20       1
# 680944   # 21b. Water available    0.0  2018     6  19       2
# 681550   # 21b. Water available    0.0  2018     6  18       2
# 738602   # 21b. Water available    0.0  2018     9  13       3
# 750199   # 21b. Water available    0.0  2018     8  24       3
# 782269   # 21b. Water available    0.0  2018    11   8       4
# 842686   # 21b. Water available    0.0  2019     3  14       1
# 845015   # 21b. Water available    0.0  2019     2   6       1
# 936356   # 21b. Water available    0.0  2019     8   1       3
# 955404   # 21b. Water available    0.0  2019     7   2       3
# 981267   # 21b. Water available    0.0  2019     7   9       3
# 983568   # 21b. Water available    0.0  2019     6   4       2
# 993597   # 21b. Water available    0.0  2019     8  21       3
# 1013808  # 21b. Water available    0.0  2019     9   3       3
# 1059286  # 21b. Water available    0.0  2019    12  17       4
# 1087624  # 21b. Water available    0.0  2019    10  25       4
# 1126671  # 21b. Water available    0.0  2020     1  22       1
# 1196172  # 21b. Water available    0.0  2020     8  17       3
#
# [47 rows x 27 columns]

# %%
merged_df[merged_df['serial_number']=='DAH5EMEOW']
# 0.0 points with a violation --> duplicate values!!!
# Out:
#        activity_date   owner_id owner_name facility_id        facility_name  \
# 205817    2016-06-07  OW0030630  ROMAN INC   FA0037751  MARISCOS SAN ISIDRO
# 205818    2016-06-07  OW0030630  ROMAN INC   FA0037751  MARISCOS SAN ISIDRO
# 205819    2016-06-07  OW0030630  ROMAN INC   FA0037751  MARISCOS SAN ISIDRO
# 205820    2016-06-07  OW0030630  ROMAN INC   FA0037751  MARISCOS SAN ISIDRO
#
#         record_id         program_name program_status  program_element_(pe)  \
# 205817  PR0001060  MARISCOS SAN ISIDRO         ACTIVE                  1638
# 205818  PR0001060  MARISCOS SAN ISIDRO         ACTIVE                  1638
# 205819  PR0001060  MARISCOS SAN ISIDRO         ACTIVE                  1638
# 205820  PR0001060  MARISCOS SAN ISIDRO         ACTIVE                  1638
#
#                              pe_description  ... serial_number employee_id  \
# 205817  RESTAURANT (61-150) SEATS HIGH RISK  ...     DAH5EMEOW   EE0000592
# 205818  RESTAURANT (61-150) SEATS HIGH RISK  ...     DAH5EMEOW   EE0000592
# 205819  RESTAURANT (61-150) SEATS HIGH RISK  ...     DAH5EMEOW   EE0000592
# 205820  RESTAURANT (61-150) SEATS HIGH RISK  ...     DAH5EMEOW   EE0000592
#
#         violation__status  violation_code  \
# 205817  OUT OF COMPLIANCE            F014
# 205818  OUT OF COMPLIANCE            F021
# 205819  OUT OF COMPLIANCE            F021
# 205820  OUT OF COMPLIANCE            F052
#
#                                    violation_description points  year month  \
# 205817  # 14. Food contact surfaces: clean and sanitized    4.0  2016     6
# 205818                            # 21b. Water available    4.0  2016     6
# 205819                            # 21b. Water available    0.0  2016     6
# 205820                  # 01b. Food safety certification    2.0  2016     6
#
#        day quarter
# 205817   7       2
# 205818   7       2
# 205819   7       2
# 205820   7       2
#
# [4 rows x 27 columns]

# %%
crit_code = ['F021','F022','F023']
maj_code = ['F002','F005','F007','F008','F009','F010','F011','F013','F014','F015','F020','F021','F022','F023','F054']
min_code = maj_code + ['F001','F003','F004','F006','F012','F016','F017','F018','F019','F022','F023','F052']
ret_code = ['F024','F025','F026','F027','F028','F029','F030','F031','F032','F033','F034','F035','F036','F037','F038',
            'F039','F040','F041','F042','F043','F044','F045','F046','F048']

# %%
conditions = [merged_df['violation_code'].isin(crit_code) & (merged_df['points'] == 11.0),\
              merged_df['violation_code'].isin(maj_code) & (merged_df['points'] == 4.0),\
              merged_df['violation_code'].isin(min_code) & (merged_df['points'] == 2.0),\
              merged_df['violation_code'].isin(ret_code) & (merged_df['points'] == 1.0),\
              merged_df['violation_code'].isin(maj_code) & (merged_df['points'] == 3.0)]

merged_df['violation_category'] = np.select(conditions, ['Critical','Major','Minor','Retail','DoubleMajor'], default = np.nan)

# %%
merged_df.head()
# Out:
#   activity_date   owner_id        owner_name facility_id   facility_name  \
# 0    2015-11-10  OW0126532  GEN TORRANCE LLC   FA0162834  GEN KOREAN BBQ
# 1    2015-11-10  OW0126532  GEN TORRANCE LLC   FA0162834  GEN KOREAN BBQ
# 2    2015-11-10  OW0126532  GEN TORRANCE LLC   FA0162834  GEN KOREAN BBQ
# 3    2015-11-10  OW0126532  GEN TORRANCE LLC   FA0162834  GEN KOREAN BBQ
# 4    2015-11-10  OW0126532  GEN TORRANCE LLC   FA0162834  GEN KOREAN BBQ
#
#    record_id    program_name program_status  program_element_(pe)  \
# 0  PR0150985  GEN KOREAN BBQ         ACTIVE                  1638
# 1  PR0150985  GEN KOREAN BBQ         ACTIVE                  1638
# 2  PR0150985  GEN KOREAN BBQ         ACTIVE                  1638
# 3  PR0150985  GEN KOREAN BBQ         ACTIVE                  1638
# 4  PR0150985  GEN KOREAN BBQ         ACTIVE                  1638
#
#                         pe_description  ... employee_id  violation__status  \
# 0  RESTAURANT (61-150) SEATS HIGH RISK  ...   EE0000306  OUT OF COMPLIANCE
# 1  RESTAURANT (61-150) SEATS HIGH RISK  ...   EE0000306  OUT OF COMPLIANCE
# 2  RESTAURANT (61-150) SEATS HIGH RISK  ...   EE0000306  OUT OF COMPLIANCE
# 3  RESTAURANT (61-150) SEATS HIGH RISK  ...   EE0000306  OUT OF COMPLIANCE
# 4  RESTAURANT (61-150) SEATS HIGH RISK  ...   EE0000306  OUT OF COMPLIANCE
#
#   violation_code                              violation_description  points  \
# 0           F027                 # 27. Food separated and protected     1.0
# 1           F037  # 37. Adequate ventilation and lighting; desig...     1.0
# 2           F040  # 40. Plumbing: Plumbing in good repair, prope...     1.0
# 3           F006  # 06. Adequate handwashing facilities supplied...     2.0
# 4           F036  # 36. Equipment, utensils and linens: storage ...     1.0
#
#    year  month day quarter violation_category
# 0  2015     11  10       4             Retail
# 1  2015     11  10       4             Retail
# 2  2015     11  10       4             Retail
# 3  2015     11  10       4              Minor
# 4  2015     11  10       4             Retail
#
# [5 rows x 28 columns]

# %% [markdown]
# ### Categorize Based on Breakdown of pe_description
# * Breakdown pe_description to facility type, size, risk level
# * Use International Building Code guidelines to Standardize Capacity --> convert seat value to square feet
# * 15 sq ft dedicated to one occupant
# * Remove non-restaurant, non-caterer and food market retail??

# %%
merged_df['pe_description'].value_counts()
# Out:
# RESTAURANT (0-30) SEATS HIGH RISK                276881
# RESTAURANT (31-60) SEATS HIGH RISK               224055
# RESTAURANT (61-150) SEATS HIGH RISK              180171
# RESTAURANT (0-30) SEATS MODERATE RISK            171401
# FOOD MKT RETAIL (1-1,999 SF) LOW RISK             74607
# RESTAURANT (151 + ) SEATS HIGH RISK               69592
# FOOD MKT RETAIL (1-1,999 SF) HIGH RISK            50050
# RESTAURANT (31-60) SEATS MODERATE RISK            33206
# FOOD MKT RETAIL (2,000+ SF) LOW RISK              32242
# RESTAURANT (61-150) SEATS MODERATE RISK           23846
# RESTAURANT (0-30) SEATS LOW RISK                  22133
# FOOD MKT RETAIL (2,000+ SF) HIGH RISK             19881
# FOOD MKT RETAIL (1-1,999 SF) MODERATE RISK        10739
# RESTAURANT (31-60) SEATS LOW RISK                  7109
# FOOD MKT RETAIL (2,000+ SF) MODERATE RISK          5874
# RESTAURANT (151 + ) SEATS MODERATE RISK            3914
# RESTAURANT (61-150) SEATS LOW RISK                 2832
# RESTAURANT (151 + ) SEATS LOW RISK                  975
# INTERIM HOUSING FF (1-1,999) SQ. FT.                262
# LIC HTH CARE FOOD FAC (4000-9999 SF)HIGH RISK       257
# CATERER (0-999 SQ. FT.)                             151
# CATERER (1,000-1,999 SQ. FT.)                       101
# PRIVATE SCHOOL CAFETERIA                             83
# INTERIM HOUSING FF (2,000-4,999) SQ. FT.             75
# WHOLESALE FOOD COMPLEX                               41
# FOOD PROCESSING WHOLESALE (2,000-5,999 SF)           35
# LIC HTH CARE FOOD FAC (10,000+ SF) HIGH RISK         25
# LIC HTH CARE FOOD FAC (2000-3999 SF)HIGH RISK        21
# FOOD PROCESSING WHOLESALE (1-1,999 SQ. FT.)          18
# FOOD MARKET WHOLESALE                                17
# FOOD PROCESSING WHOLESALE (6,000 + SQ. FT.)          14
# FOOD WAREHOUSE (1-4,999) SQ. FT.                      9
# FOOD VEHICLE COMMISSARY (0-10)                        8
# FOOD WAREHOUSE (5,000 + ) SQ. FT.                     7
# SENIOR FEEDING SITE                                   6
# LIC HTH CARE FOOD FAC (0-1999 SF) MOD RISK            5
# LIC HTH CARE FOOD FAC (0-1999 SF) HIGH RISK           5
# PC - COMMISSARY                                       3
# SWAP MEET PREPACKAGED FOOD STAND                      1
# CATERER (2,000 + SQ. FT.)                             1
# Name: pe_description, dtype: int64

# %% [markdown]
# ### Drop Duplicates

# %%
# Serial numbers are unique for each inspection. 
dropped_dup = merged_df.drop_duplicates(subset = ['serial_number'], keep = 'first')
dropped_dup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 386336 entries, 0 to 1210646
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   activity_date          386336 non-null  datetime64[ns]
#  1   owner_id               386336 non-null  object
#  2   owner_name             386336 non-null  object
#  3   facility_id            386336 non-null  object
#  4   facility_name          386336 non-null  object
#  5   record_id              386336 non-null  object
#  6   program_name           386336 non-null  object
#  7   program_status         386336 non-null  object
#  8   program_element_(pe)   386336 non-null  int64
#  9   pe_description         386336 non-null  object
#  10  facility_address       386336 non-null  object
#  11  facility_city          386336 non-null  object
#  12  facility_state         386336 non-null  object
#  13  facility_zip           386336 non-null  int64
#  14  service_code           386336 non-null  int64
#  15  service_description    386336 non-null  object
#  16  score                  386336 non-null  int64
#  17  serial_number          386336 non-null  object
#  18  employee_id            386336 non-null  object
#  19  violation__status      223921 non-null  object
#  20  violation_code         223921 non-null  object
#  21  violation_description  223921 non-null  object
#  22  points                 223921 non-null  float64
#  23  year                   386336 non-null  int64
#  24  month                  386336 non-null  int64
#  25  day                    386336 non-null  int64
#  26  quarter                386336 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(8), object(17)
# memory usage: 82.5+ MB

# %% [markdown]
# ### Notes
# * There were 386336 inspections since 2015
# * There are some missing violation information - Points, Violation_status, violation_code, violation_description
#
# ### Number of Inspections Yearly, Monthly, and by Day of Month

# %%
fig, ax = plt.subplots(3, 1, figsize = (10,20))

for idx, time in enumerate(['year','month','day']):

    ct = dropped_dup[time].value_counts().sort_index()
    
    ax[idx] = sns.barplot(x = ct.index, y = ct.values, order = ct.index, ax = ax[idx])
    
    ax[idx].set_xlabel(time)
    ax[idx].set_ylabel('Frequency')
    ax[idx].set_title('Inspection Frequency {}'.format(time))
    
    rects = ax[idx].patches
    labels = ct.values
    
    for rect, label in zip(rects,labels):
        x = rect.get_x() + rect.get_width()/2
        y = rect.get_height() + 5
        ax[idx].text(x,y,label, ha = 'center', va = 'bottom')
    
plt.show()

# %% [markdown]
# ### Quartely and Monthly Inspection Count by Year

# %%
#Quarterly Inspection Count by Year

fig, ax = plt.subplots(6,1, figsize = (10,20))
years = [2015,2016,2017,2018,2019,2020]

for idx, year in enumerate(years):

    cnt = dropped_dup[dropped_dup['year']==year]['quarter'].value_counts().sort_index()
    
    ax[idx] = cnt.plot.bar(ax = ax[idx])
    
    ax[idx].set_xlabel(time)
    ax[idx].set_ylabel('Frequency')
    ax[idx].set_title('Inspection Frequency by Quarter for {}'.format(year))
    fig.tight_layout(pad = 0.3)
    
    rects = ax[idx].patches
    labels = cnt.values
    
    for rect, label in zip(rects,labels):
        x = rect.get_x() + rect.get_width()/2
        y = rect.get_height() + 5
        ax[idx].text(x,y,label, ha = 'center', va = 'bottom')
        
plt.show()

# %%
#Monthly Inspection Count by Year

fig, ax = plt.subplots(6,1, figsize = (10,20))
years = [2015,2016,2017,2018,2019,2020]

for idx, year in enumerate(years):

    cnt = dropped_dup[dropped_dup['year']==year]['month'].value_counts().sort_index()
    
    ax[idx] = cnt.plot.bar(ax = ax[idx])
    
    ax[idx].set_xlabel('Month')
    ax[idx].set_ylabel('Frequency')
    ax[idx].set_title('Inspection Frequency by Month for {}'.format(year))
    fig.tight_layout(pad = 0.3)
    
    rects = ax[idx].patches
    labels = cnt.values
    
    for rect, label in zip(rects,labels):
        x = rect.get_x() + rect.get_width()/2
        y = rect.get_height() + 5
        ax[idx].text(x,y,label, ha = 'center', va = 'bottom')
        
plt.show()

# %% [markdown]
# * Zip Analysis with duplicates removed!

# %% [markdown]
# ### Score Distribution on Dropped Duplicate Serial Numbers

# %%
fig, ax = plt.subplots(6,1, figsize = (5,20))
years = [2015,2016,2017,2018,2019,2020]

for idx, year in enumerate(years):

    data = dropped_dup[dropped_dup['year']==year]
    sns.boxplot(x='quarter',y='score',data = data,ax = ax[idx])
    
   
    ax[idx].set_xlabel('Quarter')
    ax[idx].set_ylabel('Score')
    ax[idx].set_title('Quarterly Score Distribution for {}'.format(year))
    fig.tight_layout(pad = 0.3)
    
       
plt.show()

# %%
dropped_dup.groupby(['year','quarter'])['score'].describe()
# Out:
#                 count       mean       std   min   25%   50%   75%    max
# year quarter
# 2015 4        17937.0  93.605508  3.821352  68.0  91.0  94.0  96.0  100.0
# 2016 1        20214.0  93.953646  3.623240  70.0  92.0  94.0  97.0  100.0
#      2        21855.0  93.690368  3.731921  67.0  91.0  94.0  96.0  100.0
#      3        19616.0  93.861185  3.683232  65.0  91.0  94.0  97.0  100.0
#      4        18304.0  94.008687  3.588438  70.0  92.0  94.0  97.0  100.0
# 2017 1        19920.0  94.036898  3.823638  62.0  92.0  95.0  97.0  100.0
#      2        19269.0  93.750272  3.936281  59.0  91.0  94.0  97.0  100.0
#      3        18046.0  93.397761  4.239811  54.0  91.0  94.0  96.0  100.0
#      4        18817.0  93.703088  4.023476  57.0  91.0  94.0  97.0  100.0
# 2018 1        19881.0  93.858810  3.954652  61.0  92.0  94.0  97.0  100.0
#      2        22391.0  93.860971  3.829158  64.0  92.0  94.0  97.0  100.0
#      3        21841.0  93.718191  4.037499  64.0  92.0  94.0  97.0  100.0
#      4        18840.0  93.884076  3.874421  52.0  92.0  94.0  97.0  100.0
# 2019 1        22471.0  94.087179  3.763610  58.0  92.0  95.0  97.0  100.0
#      2        21886.0  93.905510  3.769862  65.0  92.0  94.0  97.0  100.0
#      3        21206.0  93.529096  4.086183  59.0  91.0  94.0  96.0  100.0
#      4        19335.0  93.749211  3.954359  54.0  92.0  94.0  97.0  100.0
# 2020 1        17958.0  94.066099  3.666231  65.0  92.0  95.0  97.0  100.0
#      2        13827.0  95.364794  3.318979   3.0  94.0  96.0  98.0  100.0
#      3        12722.0  95.015092  3.407233  63.0  93.0  96.0  97.0  100.0

# %%
fig, ax = plt.subplots(6,1, figsize = (5,20))
years = [2015,2016,2017,2018,2019,2020]

for idx, year in enumerate(years):

    data = dropped_dup[dropped_dup['year']==year]
    sns.boxplot(x='month',y='score',data = data,ax = ax[idx])
    
   
    ax[idx].set_xlabel('Month')
    ax[idx].set_ylabel('Score')
    ax[idx].set_title('Monthly Score Distribution for {}'.format(year))
    fig.tight_layout(pad = 0.3)
    
       
plt.show()

# %%
dropped_dup.groupby(['year','month'])['score'].describe()
# Out:
#              count       mean       std   min   25%   50%   75%    max
# year month
# 2015 10     6357.0  93.374390  3.988675  69.0  91.0  94.0  96.0  100.0
#      11     5060.0  93.630040  3.814316  68.0  91.0  94.0  96.0  100.0
#      12     6520.0  93.811810  3.644127  70.0  91.0  94.0  96.0  100.0
# 2016 1      6440.0  93.996429  3.556194  72.0  92.0  94.0  97.0  100.0
#      2      6945.0  94.116199  3.539630  70.0  92.0  95.0  97.0  100.0
#      3      6829.0  93.747987  3.758164  70.0  91.0  94.0  97.0  100.0
#      4      6470.0  93.799536  3.704518  68.0  91.0  94.0  97.0  100.0
#      5      7331.0  93.743282  3.720979  67.0  91.0  94.0  97.0  100.0
#      6      8054.0  93.554507  3.760057  70.0  91.0  94.0  96.0  100.0
#      7      5310.0  94.021846  3.556859  72.0  92.0  94.0  97.0  100.0
#      8      7629.0  93.834185  3.728377  70.0  91.0  94.0  97.0  100.0
#      9      6677.0  93.764265  3.726232  65.0  91.0  94.0  97.0  100.0
#      10     6038.0  93.908910  3.707097  70.0  91.0  94.0  97.0  100.0
#      11     5894.0  93.912623  3.591759  72.0  92.0  94.0  97.0  100.0
#      12     6372.0  94.192090  3.462218  76.0  92.0  95.0  97.0  100.0
# 2017 1      6453.0  94.090346  3.774780  72.0  92.0  95.0  97.0  100.0
#      2      6378.0  94.118062  3.853644  62.0  92.0  95.0  97.0  100.0
#      3      7089.0  93.915221  3.838185  64.0  92.0  94.0  97.0  100.0
#      4      5912.0  93.826624  3.995415  59.0  92.0  94.0  97.0  100.0
#      5      6660.0  93.792793  3.787493  72.0  92.0  94.0  97.0  100.0
#      6      6697.0  93.640585  4.026011  64.0  91.0  94.0  96.0  100.0
#      7      5748.0  93.491127  4.159190  54.0  91.0  94.0  96.0  100.0
#      8      6505.0  93.252114  4.303388  58.0  91.0  94.0  96.0  100.0
#      9      5793.0  93.468669  4.243425  55.0  91.0  94.0  96.0  100.0
#      10     6716.0  93.391007  4.227612  63.0  91.0  94.0  96.0  100.0
#      11     6147.0  93.728648  3.935855  71.0  91.0  94.0  97.0  100.0
#      12     5954.0  94.028720  3.846721  57.0  92.0  95.0  97.0  100.0
# 2018 1      6615.0  93.803930  4.114382  61.0  92.0  94.0  97.0  100.0
#      2      6389.0  93.807951  3.959433  62.0  92.0  94.0  97.0  100.0
#      3      6877.0  93.958848  3.788615  70.0  92.0  94.0  97.0  100.0
#      4      7355.0  93.844460  3.881156  64.0  92.0  94.0  97.0  100.0
#      5      7915.0  93.812129  3.888866  65.0  92.0  94.0  96.0  100.0
#      6      7121.0  93.932313  3.705700  67.0  92.0  94.0  97.0  100.0
#      7      6905.0  93.857350  3.907359  64.0  92.0  94.0  97.0  100.0
#      8      7712.0  93.661437  3.997584  66.0  91.0  94.0  96.0  100.0
#      9      7224.0  93.645764  4.196352  65.0  91.0  94.0  97.0  100.0
#      10     8115.0  93.600493  4.064655  60.0  91.0  94.0  96.0  100.0
#      11     5307.0  94.006218  3.690607  70.0  92.0  94.0  97.0  100.0
#      12     5418.0  94.189184  3.726705  52.0  92.0  95.0  97.0  100.0
# 2019 1      8347.0  94.213849  3.805719  58.0  92.0  95.0  97.0  100.0
#      2      6724.0  93.992415  3.806971  68.0  92.0  94.0  97.0  100.0
#      3      7400.0  94.030405  3.671689  62.0  92.0  94.0  97.0  100.0
#      4      7764.0  93.916151  3.705270  66.0  92.0  94.0  97.0  100.0
#      5      7546.0  94.004373  3.664760  65.0  92.0  94.0  97.0  100.0
#      6      6576.0  93.779501  3.956729  66.0  92.0  94.0  96.0  100.0
#      7      6761.0  93.590149  4.064191  60.0  91.0  94.0  96.0  100.0
#      8      7191.0  93.505771  4.098229  59.0  91.0  94.0  96.0  100.0
#      9      7254.0  93.495313  4.094589  63.0  91.0  94.0  96.0  100.0
#      10     7528.0  93.270590  4.308667  54.0  91.0  94.0  96.0  100.0
#      11     5763.0  94.034184  3.714897  70.0  92.0  95.0  97.0  100.0
#      12     6044.0  94.073627  3.643974  71.0  92.0  95.0  97.0  100.0
# 2020 1      7490.0  94.128171  3.637297  65.0  92.0  95.0  97.0  100.0
#      2      7022.0  93.975648  3.653463  70.0  92.0  94.0  97.0  100.0
#      3      3446.0  94.115496  3.751189  65.0  92.0  95.0  97.0  100.0
#      4      4044.0  95.616963  3.509419   3.0  94.0  96.0  98.0  100.0
#      5      4971.0  95.340173  3.209511  75.0  94.0  96.0  98.0  100.0
#      6      4812.0  95.178304  3.252200  73.0  93.0  96.0  98.0  100.0
#      7      4306.0  95.092661  3.245010  63.0  93.0  96.0  97.0  100.0
#      8      4082.0  94.988241  3.585325  65.0  93.0  96.0  98.0  100.0
#      9      4334.0  94.963313  3.391834  71.0  93.0  96.0  97.0  100.0

# %% [markdown]
# * 2020 might have a transcription error with a score value of 3.
# * Use heatmap to see if there is a strong correlation with year, months, and  days
# *

# %% [markdown]
# ### Score Distrubution by Zip

# %%
zip_split = dropped_dup.groupby('facility_zip')['score'].mean().sort_values(ascending=False).reset_index(name='score')

# %%
sns.kdeplot(data = zip_split,x='score', cut = 0, bw_adjust = 0.5)
# Out:
# <AxesSubplot:xlabel='score', ylabel='Density'>

# %% [markdown]
# ### Score Distribution by Program Element - Dupllicate Removed

# %%
plt.figure(figsize=(20,10))

sns.boxplot(x = 'score',y = 'pe_description', data = dropped_dup, orient = 'h')
# Out:
# <AxesSubplot:xlabel='score', ylabel='pe_description'>

# %% [markdown]
# ### Score Distribution by Violation Type - Duplicate NOT Removed

# %% [markdown]
# ### Explore violation data

# %%
merged_df['violation__status'].value_counts()
# Out:
# OUT OF COMPLIANCE       1048234
# VIOLATION                     3
# HOUSING NON-CRITICAL          1
# Name: violation__status, dtype: int64

# %%
merged_df[merged_df['violation__status']=='VIOLATION']
# Out:
#        activity_date   owner_id           owner_name facility_id  \
# 515722    2017-10-13  OW0102120    TAWAT & SON, INC.   FA0138823
# 565367    2018-01-16  OW0007408          CHENG, EANG   FA0025782
# 857825    2019-01-23  OW0100745  PARK, SUNG H. ET AL   FA0137619
#
#                      facility_name  record_id                program_name  \
# 515722  BABY ELEPHANT THAI CUISINE  PR0123191  BABY ELEPHANT THAI CUISINE
# 565367            MR GOOD'S DONUTS  PR0010753            MR GOOD'S DONUTS
# 857825                SUSHI WAKANA  PR0121736                SUSHI WAKANA
#
#        program_status  program_element_(pe)  \
# 515722         ACTIVE                  1635
# 565367         ACTIVE                  1631
# 857825         ACTIVE                  1632
#
#                                pe_description  ... serial_number employee_id  \
# 515722     RESTAURANT (31-60) SEATS HIGH RISK  ...     DA0C0D8GJ   EE0000263
# 565367  RESTAURANT (0-30) SEATS MODERATE RISK  ...     DA3VCK59Z   EE0000821
# 857825      RESTAURANT (0-30) SEATS HIGH RISK  ...     DAI04SXIY   EE0000015
#
#        violation__status  violation_code  \
# 515722         VIOLATION            F029
# 565367         VIOLATION            F050
# 857825         VIOLATION            F050
#
#                                     violation_description points  year month  \
# 515722  # 29. Toxic substances properly identified, st...    1.0  2017    10
# 565367                            # 51. Permit Suspension    0.0  2018     1
# 857825                            # 51. Permit Suspension    0.0  2019     1
#
#        day quarter
# 515722  13       4
# 565367  16       1
# 857825  23       1
#
# [3 rows x 27 columns]

# %%
merged_df['violation_code'].unique()
# Out:
# array(['F027', 'F037', 'F040', 'F006', 'F036', 'F044', 'F033', 'F035',
#        nan, 'F042', 'F039', 'F030', 'F007', 'F052', 'F004', 'F029',
#        'F014', 'F038', 'F043', 'F001', 'F034', 'F048', 'F032', 'F023',
#        'F021', 'F046', 'F025', 'F013', 'F041', 'F005', 'F026', 'F049',
#        'F016', 'F031', 'F009', 'F053', 'F022', 'F050', 'F055', 'F054',
#        'F008', 'F011', 'W024', 'W026', 'W052', 'F045', 'F024', 'F015',
#        'F018', 'F002', 'F028', 'F019', 'F047', 'F010', 'W028', 'W034',
#        'F012', 'F003', 'W005', 'W047', 'W001', 'W051', 'W006', 'F051',
#        'W053', 'W011', 'F017', 'W023', 'SF15', 'W041', 'W027', 'W014',
#        'W044', 'W020', 'W050', 'W017', 'W003', 'W031', 'W039', 'W004',
#        'W016', 'F058', 'F057', 'W029', 'H102', 'F056', 'W048', 'W035',
#        'W019', 'W033', 'W021', 'W032', 'MF08', 'MF45', 'MF36', 'F020',
#        'W022', 'W025', 'W030', 'W007', 'MP15', 'CV30', 'CV31', 'CV27',
#        'CV45', 'CV29'], dtype=object)

# %% [markdown]
# * Check out F002, F005, F007-F011, F013-F15, F20-23 and F50 which is permit suspension

# %%
lst = ['F002','F005','F007','F008','F009','F010','F011','F013','F014','F015','F020','F021','F022','F023','F050']


b = pd.DataFrame()
for i in lst:
    a = merged_df[merged_df['violation_code']==i].head(2)
    b = b.append(a)
b
# Out:
#         activity_date   owner_id                              owner_name  \
# 3002       2015-11-12  OW0184217                     LARSEN'S STEAKHOUSE
# 49482      2015-11-14  OW0128454                           JIN CONG WANG
# 169        2016-04-28  OW0106857        FC JUICE PARTNERS CALIFORNIA LLC
# 326        2016-09-19  OW0006768                    CERRITOS L AND L INC
# 22         2015-12-16  OW0031302                        SALAZAR, RAMON R
# 36         2015-12-30  OW0012090            FONDA DON CHON RESTAURANT IN
# 702        2018-01-03  OW0242515                      KATSUNORI HISANAGA
# 734        2018-02-21  OW0036648                         TSIBOUKAS, ALEX
# 345        2016-10-13  OW0039327                            WU JIAN YANG
# 384        2016-12-08  OW0025317                            MUNDANAS INC
# 10548      2015-10-09  OW0007608            CHIPOTLE MEXICAN GRILL, INC.
# 33481      2015-10-14  OW0115428  SOUTHERN CALIFORNIA FLOATING CHRISTIAN
# 736        2018-02-21  OW0036648                         TSIBOUKAS, ALEX
# 2790       2015-10-30  OW0005076                           BOTECO 1, LLC
# 135        2016-04-07  OW0003092                           AROYAN MOVSES
# 207        2016-05-26  OW0016489                    HTC RESTAURANT GROUP
# 42         2016-01-06  OW0035172                        TEA KITCHEN INC.
# 52         2016-01-19  OW0099386                          BAZIKYAN, INC.
# 2144       2015-10-27  OW0012042                         FLORES, MARIA M
# 4117       2015-11-17  OW0036933                       FICHI GROUP, INC.
# 771017     2018-12-03  OW0009005            CRENSHAW CHRISTIAN CENTER/FS
# 1145366    2020-01-21  OW0238075                   DE TOLEDO HIGH SCHOOL
# 93         2016-03-04  OW0208580                        BATANG GALAS LLC
# 103        2016-03-10  OW0037907                              VILLA,JOSE
# 545        2017-07-17  OW0007871                          CHOP STOP INC.
# 2413       2015-10-06  OW0012337                 FREEMAN PIZZA COMPANIES
# 84         2016-02-16  OW0014882                               HARO,NINA
# 197        2016-05-11  OW0123870                       GELATERIA ULI LLC
# 547        2017-07-17  OW0007871                          CHOP STOP INC.
# 1157       2019-09-19  OW0015594                          HIRANI, DHANJI
#
#         facility_id                          facility_name  record_id  \
# 3002      FA0178473                    LARSEN'S STEAKHOUSE  PR0171905
# 49482     FA0165172                      U.S. CHINESE FOOD  PR0153487
# 169       FA0222662                            JAMBA JUICE  PR0177688
# 326       FA0032778              L AND L HAWAIIAN BARBEQUE  PR0000718
# 22        FA0045003                        R & R SOUL FOOD  PR0038525
# 36        FA0013838                         FONDA DON CHON  PR0039266
# 702       FA0248008                                    YUI  PR0196669
# 734       FA0022626                   FANTASTIC CHARBURGER  PR0024069
# 345       FA0041601                      YANG'S RESTAURANT  PR0029227
# 384       FA0021345                             LAS ANITAS  PR0032340
# 10548     FA0059744                 CHIPOTLE MEXICAN GRILL  PR0019760
# 33481     FA0150246                   BEACON LIGHT MISSION  PR0135724
# 736       FA0022626                   FANTASTIC CHARBURGER  PR0024069
# 2790      FA0058594                     BOTECO-28 WEST BAR  PR0044442
# 135       FA0041218                               MOISHE'S  PR0042110
# 207       FA0044566                    PRESIDENT THAI CAFE  PR0036809
# 42        FA0036716                     TEN RENS TEA TI ME  PR0003478
# 52        FA0136733                             CAFE BRAVO  PR0119951
# 2144      FA0065508             LATINOS 99~ DISCOUNT STORE  PR0005449
# 4117      FA0040981                   SEAFOOD RANCH MARKET  PR0036856
# 771017    FA0017223              CRENSHAW CHRISTIAN CENTER  PR0047447
# 1145366   FA0242463  DE TOLEDO HS/NEW  COMMUNITY JEWISH HS  PR0198221
# 93        FA0203383                                  SILOG  PR0175729
# 103       FA0056404                                CARAMBA  PR0016031
# 545       FA0059770                              CHOP STOP  PR0023182
# 2413      FA0036486                   LITTLE CAESARS PIZZA  PR0020131
# 84        FA0065055                              LA CABANA  PR0019043
# 197       FA0158822                          GELATERIA ULI  PR0146902
# 547       FA0059770                              CHOP STOP  PR0023182
# 1157      FA0013412                             FARM FRESH  PR0017067
#
#                                program_name program_status  \
# 3002                    LARSEN'S STEAKHOUSE         ACTIVE
# 49482                     U.S. CHINESE FOOD       INACTIVE
# 169                             JAMBA JUICE         ACTIVE
# 326               L AND L HAWAIIAN BARBEQUE       INACTIVE
# 22                          R & R SOUL FOOD         ACTIVE
# 36                           FONDA DON CHON         ACTIVE
# 702                                     YUI         ACTIVE
# 734                    FANTASTIC CHARBURGER         ACTIVE
# 345                       YANG'S RESTAURANT         ACTIVE
# 384                              LAS ANITAS         ACTIVE
# 10548                CHIPOTLE MEXICAN GRILL         ACTIVE
# 33481          BEACON LIGHT MISSION KITCHEN         ACTIVE
# 736                    FANTASTIC CHARBURGER         ACTIVE
# 2790                     BOTECO-28 WEST BAR         ACTIVE
# 135                                MOISHE'S         ACTIVE
# 207                     PRESIDENT THAI CAFE         ACTIVE
# 42                       TEN RENS TEA TI ME         ACTIVE
# 52                               CAFE BRAVO       INACTIVE
# 2144             LATINOS 99~ DISCOUNT STORE       INACTIVE
# 4117                   SEAFOOD RANCH MARKET         ACTIVE
# 771017            CRENSHAW CHRISTIAN CENTER         ACTIVE
# 1145366  DE TOLEDO HIGH SCHOOL- JAG'S SHACK         ACTIVE
# 93                                    SILOG         ACTIVE
# 103                                 CARAMBA         ACTIVE
# 545                               CHOP STOP         ACTIVE
# 2413                   LITTLE CAESARS PIZZA         ACTIVE
# 84                                LA CABANA       INACTIVE
# 197                           GELATERIA ULI         ACTIVE
# 547                               CHOP STOP         ACTIVE
# 1157                             FARM FRESH         ACTIVE
#
#          program_element_(pe)                              pe_description  \
# 3002                     1641         RESTAURANT (151 + ) SEATS HIGH RISK
# 49482                    1632           RESTAURANT (0-30) SEATS HIGH RISK
# 169                      1631       RESTAURANT (0-30) SEATS MODERATE RISK
# 326                      1635          RESTAURANT (31-60) SEATS HIGH RISK
# 22                       1635          RESTAURANT (31-60) SEATS HIGH RISK
# 36                       1638         RESTAURANT (61-150) SEATS HIGH RISK
# 702                      1632           RESTAURANT (0-30) SEATS HIGH RISK
# 734                      1635          RESTAURANT (31-60) SEATS HIGH RISK
# 345                      1635          RESTAURANT (31-60) SEATS HIGH RISK
# 384                      1635          RESTAURANT (31-60) SEATS HIGH RISK
# 10548                    1635          RESTAURANT (31-60) SEATS HIGH RISK
# 33481                    1632        INTERIM HOUSING FF (1-1,999) SQ. FT.
# 736                      1635          RESTAURANT (31-60) SEATS HIGH RISK
# 2790                     1638         RESTAURANT (61-150) SEATS HIGH RISK
# 135                      1632           RESTAURANT (0-30) SEATS HIGH RISK
# 207                      1638         RESTAURANT (61-150) SEATS HIGH RISK
# 42                       1638         RESTAURANT (61-150) SEATS HIGH RISK
# 52                       1635          RESTAURANT (31-60) SEATS HIGH RISK
# 2144                     1610       FOOD MKT RETAIL (1-1,999 SF) LOW RISK
# 4117                     1615       FOOD MKT RETAIL (2,000+ SF) HIGH RISK
# 771017                   1638         RESTAURANT (61-150) SEATS HIGH RISK
# 1145366                  1610       FOOD MKT RETAIL (1-1,999 SF) LOW RISK
# 93                       1632           RESTAURANT (0-30) SEATS HIGH RISK
# 103                      1635          RESTAURANT (31-60) SEATS HIGH RISK
# 545                      1631       RESTAURANT (0-30) SEATS MODERATE RISK
# 2413                     1631       RESTAURANT (0-30) SEATS MODERATE RISK
# 84                       1638         RESTAURANT (61-150) SEATS HIGH RISK
# 197                      1631       RESTAURANT (0-30) SEATS MODERATE RISK
# 547                      1631       RESTAURANT (0-30) SEATS MODERATE RISK
# 1157                     1610  FOOD MKT RETAIL (1-1,999 SF) MODERATE RISK
#
#          ... serial_number employee_id  violation__status  violation_code  \
# 3002     ...     DAL6EY70C   EE0000573  OUT OF COMPLIANCE            F002
# 49482    ...     DAEQK1PJD   EE0000006  OUT OF COMPLIANCE            F002
# 169      ...     DA0AFLFTM   EE0000214  OUT OF COMPLIANCE            F005
# 326      ...     DA5TJBERN   EE0000029  OUT OF COMPLIANCE            F005
# 22       ...     DAI73QYXD   EE0000834  OUT OF COMPLIANCE            F007
# 36       ...     DA0475114   EE0000136  OUT OF COMPLIANCE            F007
# 702      ...     DA7SMHFGI   EE0000886  OUT OF COMPLIANCE            F008
# 734      ...     DAJELE7AE   EE0000092  OUT OF COMPLIANCE            F008
# 345      ...     DA0Q0SFMK   EE0000535  OUT OF COMPLIANCE            F009
# 384      ...     DAA0KMGOG   EE0000360  OUT OF COMPLIANCE            F009
# 10548    ...     DAMF4FHLJ   EE0000821  OUT OF COMPLIANCE            F010
# 33481    ...     DA2AW1WRO   EE0000005  OUT OF COMPLIANCE            F010
# 736      ...     DAJELE7AE   EE0000092  OUT OF COMPLIANCE            F011
# 2790     ...     DAI2STAX6   EE0000431  OUT OF COMPLIANCE            F011
# 135      ...     DAMCRE1YO   EE0000468  OUT OF COMPLIANCE            F013
# 207      ...     DAKSQ10AU   EE0000152  OUT OF COMPLIANCE            F013
# 42       ...     DAISHBTQ6   EE0000263  OUT OF COMPLIANCE            F014
# 52       ...     DA193D0SU   EE0000523  OUT OF COMPLIANCE            F014
# 2144     ...     DAJDPXZLR   EE0000684  OUT OF COMPLIANCE            F015
# 4117     ...     DA8MLYUFV   EE0000017  OUT OF COMPLIANCE            F015
# 771017   ...     DAFEZXVIB   EE0001064  OUT OF COMPLIANCE            F020
# 1145366  ...     DAAOYBO0U   EE0000262  OUT OF COMPLIANCE            F020
# 93       ...     DABU42A1U   EE0000349  OUT OF COMPLIANCE            F021
# 103      ...     DAJNG2QRC   EE0000163  OUT OF COMPLIANCE            F021
# 545      ...     DAAZYYIHM   EE0000272  OUT OF COMPLIANCE            F022
# 2413     ...     DAA92H5EC   EE0000486  OUT OF COMPLIANCE            F022
# 84       ...     DADFMRIX0   EE0000858  OUT OF COMPLIANCE            F023
# 197      ...     DAL5EG3JE   EE0000840  OUT OF COMPLIANCE            F023
# 547      ...     DAAZYYIHM   EE0000272  OUT OF COMPLIANCE            F050
# 1157     ...     DAKCVINDT   EE0000329  OUT OF COMPLIANCE            F050
#
#                                      violation_description points  year month  \
# 3002     # 02. Communicable disease; reporting, restric...    4.0  2015    11
# 49482    # 02. Communicable disease; reporting, restric...    4.0  2015    11
# 169      # 05. Hands clean and properly washed; gloves ...    4.0  2016     4
# 326      # 05. Hands clean and properly washed; gloves ...    2.0  2016     9
# 22          # 07. Proper hot and cold holding temperatures    2.0  2015    12
# 36          # 07. Proper hot and cold holding temperatures    4.0  2015    12
# 702      # 08. Time as a public health control; procedu...    2.0  2018     1
# 734      # 08. Time as a public health control; procedu...    2.0  2018     2
# 345                           # 09. Proper cooling methods    2.0  2016    10
# 384                           # 09. Proper cooling methods    4.0  2016    12
# 10548             # 10. Proper cooking time & temperatures    4.0  2015    10
# 33481             # 10. Proper cooking time & temperatures    4.0  2015    10
# 736      # 11. Proper reheating procedures for hot holding    4.0  2018     2
# 2790     # 11. Proper reheating procedures for hot holding    4.0  2015    10
# 135      # 13. Food in good condition, safe and unadult...    2.0  2016     4
# 207      # 13. Food in good condition, safe and unadult...    2.0  2016     5
# 42        # 14. Food contact surfaces: clean and sanitized    4.0  2016     1
# 52        # 14. Food contact surfaces: clean and sanitized    4.0  2016     1
# 2144              # 15. Food obtained from approved source    4.0  2015    10
# 4117              # 15. Food obtained from approved source    4.0  2015    11
# 771017   # 20. Licensed health care facilities/public &...    4.0  2018    12
# 1145366  # 20. Licensed health care facilities/public &...    4.0  2020     1
# 93                                  # 21b. Water available    4.0  2016     3
# 103                                 # 21b. Water available    2.0  2016     3
# 545          # 22. Sewage and wastewater properly disposed   11.0  2017     7
# 2413         # 22. Sewage and wastewater properly disposed    2.0  2015    10
# 84            # 23. No rodents, insects, birds, or animals    2.0  2016     2
# 197           # 23. No rodents, insects, birds, or animals    2.0  2016     5
# 547                                # 51. Permit Suspension    0.0  2017     7
# 1157                               # 51. Permit Suspension    0.0  2019     9
#
#         day quarter
# 3002     12       4
# 49482    14       4
# 169      28       2
# 326      19       3
# 22       16       4
# 36       30       4
# 702       3       1
# 734      21       1
# 345      13       4
# 384       8       4
# 10548     9       4
# 33481    14       4
# 736      21       1
# 2790     30       4
# 135       7       2
# 207      26       2
# 42        6       1
# 52       19       1
# 2144     27       4
# 4117     17       4
# 771017    3       4
# 1145366  21       1
# 93        4       1
# 103      10       1
# 545      17       3
# 2413      6       4
# 84       16       1
# 197      11       2
# 547      17       3
# 1157     19       3
#
# [30 rows x 27 columns]

# %% [markdown]
# * Filter Major Violations using pts
# ---
# #### Major Violations
# * Major Violations have a point deduction of 4pts or 11pts.
# * The violation code is lst above. --> Some violation codes can be marked as minor violations hence the conditional loop.

# %%
major_violations = merged_df.loc[(merged_df['points'] == 4.0) | (merged_df['points'] == 11.0)]
major_violations.shape
# Out:
# (50881, 27)

# %%
major_violations.hist(column = 'score', bins = 20)
# Out:
# array([[<AxesSubplot:title={'center':'score'}>]], dtype=object)

# %%
sns.kdeplot(data = major_violations,x='score', cut = 0)
# Out:
# <AxesSubplot:xlabel='score', ylabel='Density'>

# %%
major_violations['facility_zip'].value_counts().head(15)
# Out:
# 91748    1078
# 90045     923
# 90012     765
# 91754     723
# 91801     604
# 90401     537
# 90025     535
# 90015     517
# 90291     509
# 90230     464
# 93534     460
# 90703     459
# 90201     459
# 90064     456
# 90650     446
# Name: facility_zip, dtype: int64

# %%
(major_violations['record_id'] + ' : ' + major_violations['facility_name']).value_counts().head(30)
# Out:
# PR0189419 : PLANET HOLLYWOOD                20
# PR0156336 : GOLD HIBACHI BUFFET             19
# PR0170854 : HAWAIIAN BBQ HOUSE              19
# PR0031392 : BANH MI MY THO                  18
# PR0156516 : PHO BANH MI CHE CALI            16
# PR0168279 : HIBACHI GRILL BUFFET            16
# PR0028061 : CHINA BOY EXPRESS BAKERY        15
# PR0148023 : JAMES BEACH                     15
# PR0031553 : SAN SOO DANG                    15
# PR0023808 : THAI DISHES RESTAURANT          15
# PR0034955 : MONTEREY PALACE RESTAURANT      15
# PR0177458 : EAST SEAFOOD BUFFET             15
# PR0004316 : NBC SEAFOOD RESTAURANT          15
# PR0018307 : KANG KANG SHAU MAY RESTAURAN    14
# PR0039287 : HOP WOO BBQ RESTAURANT          14
# PR0010156 : NICE TIME CAFE                  14
# PR0003465 : SHAU MAY RESTAURANT             14
# PR0025993 : SAM WOO RESTAURANT              14
# PR0191208 : SUNDAY BISTRO                   14
# PR0041366 : A B C CAFE                      13
# PR0014334 : BANH MI & CHE CALI REST/MKT     13
# PR0000460 : ASIAN FASTFOOD & GROCERY        13
# PR0039580 : INTERNATIONAL BUFFET            13
# PR0016592 : LUNASIA                         13
# PR0166984 : SUPER CARNES LA PASADITA        12
# PR0029760 : GOURMET WOK                     12
# PR0042981 : MAXWELL'S BURGERS & HOT DOGS    12
# PR0121306 : DAIKOKUYA-SAWTELLE              12
# PR0200131 : GARAGE KITCHEN                  12
# PR0013471 : CLASS 302                       12
# dtype: int64

# %%
merged_df[(merged_df['record_id'] == 'PR0189419') & (merged_df['year']==2018)]
# Out:
#        activity_date   owner_id                 owner_name facility_id  \
# 593782    2018-03-06  OW0237254  PLANET EXPRESS (LAX)  LLC   FA0241313
# 593783    2018-03-06  OW0237254  PLANET EXPRESS (LAX)  LLC   FA0241313
# 593784    2018-03-06  OW0237254  PLANET EXPRESS (LAX)  LLC   FA0241313
# 593785    2018-03-06  OW0237254  PLANET EXPRESS (LAX)  LLC   FA0241313
# 593786    2018-03-06  OW0237254  PLANET EXPRESS (LAX)  LLC   FA0241313
# 604931    2018-02-16  OW0237254  PLANET EXPRESS (LAX)  LLC   FA0241313
# 604932    2018-02-16  OW0237254  PLANET EXPRESS (LAX)  LLC   FA0241313
# 604933    2018-02-16  OW0237254  PLANET EXPRESS (LAX)  LLC   FA0241313
# 604934    2018-02-16  OW0237254  PLANET EXPRESS (LAX)  LLC   FA0241313
# 604935    2018-02-16  OW0237254  PLANET EXPRESS (LAX)  LLC   FA0241313
# 604936    2018-02-16  OW0237254  PLANET EXPRESS (LAX)  LLC   FA0241313
# 604937    2018-02-16  OW0237254  PLANET EXPRESS (LAX)  LLC   FA0241313
# 604938    2018-02-16  OW0237254  PLANET EXPRESS (LAX)  LLC   FA0241313
# 604939    2018-02-16  OW0237254  PLANET EXPRESS (LAX)  LLC   FA0241313
# 604940    2018-02-16  OW0237254  PLANET EXPRESS (LAX)  LLC   FA0241313
# 604941    2018-02-16  OW0237254  PLANET EXPRESS (LAX)  LLC   FA0241313
# 604942    2018-02-16  OW0237254  PLANET EXPRESS (LAX)  LLC   FA0241313
# 697366    2018-05-29  OW0237254  PLANET EXPRESS (LAX)  LLC   FA0241313
# 697367    2018-05-29  OW0237254  PLANET EXPRESS (LAX)  LLC   FA0241313
# 697368    2018-05-29  OW0237254  PLANET EXPRESS (LAX)  LLC   FA0241313
# 697369    2018-05-29  OW0237254  PLANET EXPRESS (LAX)  LLC   FA0241313
# 697370    2018-05-29  OW0237254  PLANET EXPRESS (LAX)  LLC   FA0241313
# 697371    2018-05-29  OW0237254  PLANET EXPRESS (LAX)  LLC   FA0241313
# 697372    2018-05-29  OW0237254  PLANET EXPRESS (LAX)  LLC   FA0241313
# 697373    2018-05-29  OW0237254  PLANET EXPRESS (LAX)  LLC   FA0241313
# 697374    2018-05-29  OW0237254  PLANET EXPRESS (LAX)  LLC   FA0241313
# 750017    2018-08-24  OW0237254  PLANET EXPRESS (LAX)  LLC   FA0241313
# 750018    2018-08-24  OW0237254  PLANET EXPRESS (LAX)  LLC   FA0241313
# 750019    2018-08-24  OW0237254  PLANET EXPRESS (LAX)  LLC   FA0241313
# 750020    2018-08-24  OW0237254  PLANET EXPRESS (LAX)  LLC   FA0241313
# 750021    2018-08-24  OW0237254  PLANET EXPRESS (LAX)  LLC   FA0241313
# 750022    2018-08-24  OW0237254  PLANET EXPRESS (LAX)  LLC   FA0241313
# 750023    2018-08-24  OW0237254  PLANET EXPRESS (LAX)  LLC   FA0241313
#
#            facility_name  record_id      program_name program_status  \
# 593782  PLANET HOLLYWOOD  PR0189419  PLANET HOLLYWOOD         ACTIVE
# 593783  PLANET HOLLYWOOD  PR0189419  PLANET HOLLYWOOD         ACTIVE
# 593784  PLANET HOLLYWOOD  PR0189419  PLANET HOLLYWOOD         ACTIVE
# 593785  PLANET HOLLYWOOD  PR0189419  PLANET HOLLYWOOD         ACTIVE
# 593786  PLANET HOLLYWOOD  PR0189419  PLANET HOLLYWOOD         ACTIVE
# 604931  PLANET HOLLYWOOD  PR0189419  PLANET HOLLYWOOD         ACTIVE
# 604932  PLANET HOLLYWOOD  PR0189419  PLANET HOLLYWOOD         ACTIVE
# 604933  PLANET HOLLYWOOD  PR0189419  PLANET HOLLYWOOD         ACTIVE
# 604934  PLANET HOLLYWOOD  PR0189419  PLANET HOLLYWOOD         ACTIVE
# 604935  PLANET HOLLYWOOD  PR0189419  PLANET HOLLYWOOD         ACTIVE
# 604936  PLANET HOLLYWOOD  PR0189419  PLANET HOLLYWOOD         ACTIVE
# 604937  PLANET HOLLYWOOD  PR0189419  PLANET HOLLYWOOD         ACTIVE
# 604938  PLANET HOLLYWOOD  PR0189419  PLANET HOLLYWOOD         ACTIVE
# 604939  PLANET HOLLYWOOD  PR0189419  PLANET HOLLYWOOD         ACTIVE
# 604940  PLANET HOLLYWOOD  PR0189419  PLANET HOLLYWOOD         ACTIVE
# 604941  PLANET HOLLYWOOD  PR0189419  PLANET HOLLYWOOD         ACTIVE
# 604942  PLANET HOLLYWOOD  PR0189419  PLANET HOLLYWOOD         ACTIVE
# 697366  PLANET HOLLYWOOD  PR0189419  PLANET HOLLYWOOD         ACTIVE
# 697367  PLANET HOLLYWOOD  PR0189419  PLANET HOLLYWOOD         ACTIVE
# 697368  PLANET HOLLYWOOD  PR0189419  PLANET HOLLYWOOD         ACTIVE
# 697369  PLANET HOLLYWOOD  PR0189419  PLANET HOLLYWOOD         ACTIVE
# 697370  PLANET HOLLYWOOD  PR0189419  PLANET HOLLYWOOD         ACTIVE
# 697371  PLANET HOLLYWOOD  PR0189419  PLANET HOLLYWOOD         ACTIVE
# 697372  PLANET HOLLYWOOD  PR0189419  PLANET HOLLYWOOD         ACTIVE
# 697373  PLANET HOLLYWOOD  PR0189419  PLANET HOLLYWOOD         ACTIVE
# 697374  PLANET HOLLYWOOD  PR0189419  PLANET HOLLYWOOD         ACTIVE
# 750017  PLANET HOLLYWOOD  PR0189419  PLANET HOLLYWOOD         ACTIVE
# 750018  PLANET HOLLYWOOD  PR0189419  PLANET HOLLYWOOD         ACTIVE
# 750019  PLANET HOLLYWOOD  PR0189419  PLANET HOLLYWOOD         ACTIVE
# 750020  PLANET HOLLYWOOD  PR0189419  PLANET HOLLYWOOD         ACTIVE
# 750021  PLANET HOLLYWOOD  PR0189419  PLANET HOLLYWOOD         ACTIVE
# 750022  PLANET HOLLYWOOD  PR0189419  PLANET HOLLYWOOD         ACTIVE
# 750023  PLANET HOLLYWOOD  PR0189419  PLANET HOLLYWOOD         ACTIVE
#
#         program_element_(pe)                       pe_description  ...  \
# 593782                  1638  RESTAURANT (61-150) SEATS HIGH RISK  ...
# 593783                  1638  RESTAURANT (61-150) SEATS HIGH RISK  ...
# 593784                  1638  RESTAURANT (61-150) SEATS HIGH RISK  ...
# 593785                  1638  RESTAURANT (61-150) SEATS HIGH RISK  ...
# 593786                  1638  RESTAURANT (61-150) SEATS HIGH RISK  ...
# 604931                  1638  RESTAURANT (61-150) SEATS HIGH RISK  ...
# 604932                  1638  RESTAURANT (61-150) SEATS HIGH RISK  ...
# 604933                  1638  RESTAURANT (61-150) SEATS HIGH RISK  ...
# 604934                  1638  RESTAURANT (61-150) SEATS HIGH RISK  ...
# 604935                  1638  RESTAURANT (61-150) SEATS HIGH RISK  ...
# 604936                  1638  RESTAURANT (61-150) SEATS HIGH RISK  ...
# 604937                  1638  RESTAURANT (61-150) SEATS HIGH RISK  ...
# 604938                  1638  RESTAURANT (61-150) SEATS HIGH RISK  ...
# 604939                  1638  RESTAURANT (61-150) SEATS HIGH RISK  ...
# 604940                  1638  RESTAURANT (61-150) SEATS HIGH RISK  ...
# 604941                  1638  RESTAURANT (61-150) SEATS HIGH RISK  ...
# 604942                  1638  RESTAURANT (61-150) SEATS HIGH RISK  ...
# 697366                  1638  RESTAURANT (61-150) SEATS HIGH RISK  ...
# 697367                  1638  RESTAURANT (61-150) SEATS HIGH RISK  ...
# 697368                  1638  RESTAURANT (61-150) SEATS HIGH RISK  ...
# 697369                  1638  RESTAURANT (61-150) SEATS HIGH RISK  ...
# 697370                  1638  RESTAURANT (61-150) SEATS HIGH RISK  ...
# 697371                  1638  RESTAURANT (61-150) SEATS HIGH RISK  ...
# 697372                  1638  RESTAURANT (61-150) SEATS HIGH RISK  ...
# 697373                  1638  RESTAURANT (61-150) SEATS HIGH RISK  ...
# 697374                  1638  RESTAURANT (61-150) SEATS HIGH RISK  ...
# 750017                  1638  RESTAURANT (61-150) SEATS HIGH RISK  ...
# 750018                  1638  RESTAURANT (61-150) SEATS HIGH RISK  ...
# 750019                  1638  RESTAURANT (61-150) SEATS HIGH RISK  ...
# 750020                  1638  RESTAURANT (61-150) SEATS HIGH RISK  ...
# 750021                  1638  RESTAURANT (61-150) SEATS HIGH RISK  ...
# 750022                  1638  RESTAURANT (61-150) SEATS HIGH RISK  ...
# 750023                  1638  RESTAURANT (61-150) SEATS HIGH RISK  ...
#
#        serial_number employee_id  violation__status  violation_code  \
# 593782     DALBRVPXQ   EE0000633  OUT OF COMPLIANCE            F025
# 593783     DALBRVPXQ   EE0000633  OUT OF COMPLIANCE            F027
# 593784     DALBRVPXQ   EE0000633  OUT OF COMPLIANCE            F040
# 593785     DALBRVPXQ   EE0000633  OUT OF COMPLIANCE            F035
# 593786     DALBRVPXQ   EE0000633  OUT OF COMPLIANCE            F033
# 604931     DA9YWV0YB   EE0000633  OUT OF COMPLIANCE            F044
# 604932     DA9YWV0YB   EE0000633  OUT OF COMPLIANCE            F049
# 604933     DA9YWV0YB   EE0000633  OUT OF COMPLIANCE            F040
# 604934     DA9YWV0YB   EE0000633  OUT OF COMPLIANCE            F037
# 604935     DA9YWV0YB   EE0000633  OUT OF COMPLIANCE            F054
# 604936     DA9YWV0YB   EE0000633  OUT OF COMPLIANCE            F043
# 604937     DA9YWV0YB   EE0000633  OUT OF COMPLIANCE            F026
# 604938     DA9YWV0YB   EE0000633  OUT OF COMPLIANCE            F009
# 604939     DA9YWV0YB   EE0000633  OUT OF COMPLIANCE            F035
# 604940     DA9YWV0YB   EE0000633  OUT OF COMPLIANCE            F007
# 604941     DA9YWV0YB   EE0000633  OUT OF COMPLIANCE            F005
# 604942     DA9YWV0YB   EE0000633  OUT OF COMPLIANCE            F033
# 697366     DA314R0EP   EE0000633  OUT OF COMPLIANCE            F033
# 697367     DA314R0EP   EE0000633  OUT OF COMPLIANCE            F014
# 697368     DA314R0EP   EE0000633  OUT OF COMPLIANCE            F007
# 697369     DA314R0EP   EE0000633  OUT OF COMPLIANCE            F035
# 697370     DA314R0EP   EE0000633  OUT OF COMPLIANCE            F040
# 697371     DA314R0EP   EE0000633  OUT OF COMPLIANCE            F037
# 697372     DA314R0EP   EE0000633  OUT OF COMPLIANCE            F054
# 697373     DA314R0EP   EE0000633  OUT OF COMPLIANCE            F049
# 697374     DA314R0EP   EE0000633  OUT OF COMPLIANCE            F044
# 750017     DA0ZBUOZO   EE0000633  OUT OF COMPLIANCE            F044
# 750018     DA0ZBUOZO   EE0000633  OUT OF COMPLIANCE            F040
# 750019     DA0ZBUOZO   EE0000633  OUT OF COMPLIANCE            F030
# 750020     DA0ZBUOZO   EE0000633  OUT OF COMPLIANCE            F035
# 750021     DA0ZBUOZO   EE0000633  OUT OF COMPLIANCE            F034
# 750022     DA0ZBUOZO   EE0000633  OUT OF COMPLIANCE            F033
# 750023     DA0ZBUOZO   EE0000633  OUT OF COMPLIANCE            F023
#
#                                     violation_description points  year month  \
# 593782     # 25. Personal cleanliness and hair restraints    1.0  2018     3
# 593783                 # 27. Food separated and protected    1.0  2018     3
# 593784  # 40. Plumbing: Plumbing in good repair, prope...    1.0  2018     3
# 593785  # 35. Equipment/Utensils - approved; installed...    1.0  2018     3
# 593786  # 33. Nonfood-contact surfaces clean and in go...    1.0  2018     3
# 604931  # 44. Floors, walls and ceilings: properly bui...    1.0  2018     2
# 604932  # 50. Impoundment of unsanitary equipment or food    0.0  2018     2
# 604933  # 40. Plumbing: Plumbing in good repair, prope...    1.0  2018     2
# 604934  # 37. Adequate ventilation and lighting; desig...    1.0  2018     2
# 604935  # 52. Multiple Major Critical Violations / Inc...    3.0  2018     2
# 604936  # 43. Premises; personal/cleaning items; vermi...    1.0  2018     2
# 604937  # 26. Approved thawing methods used, frozen fo...    1.0  2018     2
# 604938                       # 09. Proper cooling methods    4.0  2018     2
# 604939  # 35. Equipment/Utensils - approved; installed...    1.0  2018     2
# 604940     # 07. Proper hot and cold holding temperatures    2.0  2018     2
# 604941  # 05. Hands clean and properly washed; gloves ...    4.0  2018     2
# 604942  # 33. Nonfood-contact surfaces clean and in go...    1.0  2018     2
# 697366  # 33. Nonfood-contact surfaces clean and in go...    1.0  2018     5
# 697367   # 14. Food contact surfaces: clean and sanitized    4.0  2018     5
# 697368     # 07. Proper hot and cold holding temperatures    4.0  2018     5
# 697369  # 35. Equipment/Utensils - approved; installed...    1.0  2018     5
# 697370  # 40. Plumbing: Plumbing in good repair, prope...    1.0  2018     5
# 697371  # 37. Adequate ventilation and lighting; desig...    1.0  2018     5
# 697372  # 52. Multiple Major Critical Violations / Inc...    3.0  2018     5
# 697373  # 50. Impoundment of unsanitary equipment or food    0.0  2018     5
# 697374  # 44. Floors, walls and ceilings: properly bui...    1.0  2018     5
# 750017  # 44. Floors, walls and ceilings: properly bui...    1.0  2018     8
# 750018  # 40. Plumbing: Plumbing in good repair, prope...    1.0  2018     8
# 750019  # 30. Food properly stored; food storage conta...    1.0  2018     8
# 750020  # 35. Equipment/Utensils - approved; installed...    1.0  2018     8
# 750021  # 34. Warewashing facilities: Adequate, mainta...    1.0  2018     8
# 750022  # 33. Nonfood-contact surfaces clean and in go...    1.0  2018     8
# 750023       # 23. No rodents, insects, birds, or animals    2.0  2018     8
#
#        day quarter
# 593782   6       1
# 593783   6       1
# 593784   6       1
# 593785   6       1
# 593786   6       1
# 604931  16       1
# 604932  16       1
# 604933  16       1
# 604934  16       1
# 604935  16       1
# 604936  16       1
# 604937  16       1
# 604938  16       1
# 604939  16       1
# 604940  16       1
# 604941  16       1
# 604942  16       1
# 697366  29       2
# 697367  29       2
# 697368  29       2
# 697369  29       2
# 697370  29       2
# 697371  29       2
# 697372  29       2
# 697373  29       2
# 697374  29       2
# 750017  24       3
# 750018  24       3
# 750019  24       3
# 750020  24       3
# 750021  24       3
# 750022  24       3
# 750023  24       3
#
# [33 rows x 27 columns]

# %%
plt.figure(figsize=(40,10))

sns.boxplot(x = 'score',y = 'violation_description', data = merged_df, orient = 'h')
# Out:
# <AxesSubplot:xlabel='score', ylabel='violation_description'>

# %% [markdown]
# ### Major Risks and Closure

# %% [markdown]
# ### Categorizing Critical Risk (Minor & Major), Good Retail Practices, and Compliance Violations

# %%
merged_df['points'].value_counts(dropna=False)

# %% [markdown]
# ### Notes about points
# * 4 pts is MAJOR VIOLATION
# * 3 pts is the additional reduction for two major violations
# * 2 pts is a Minor Violation
# * 1 pt is Good Retail Practices Violation
# * Permit suspension due to vermin infestation, no water, or now sewage available, additional 7pt deduction for each closure type -> 4 + 7 = 11 so 11 pts must be one of those
# * What are the NaN Values and What are the 0.0 Values?

# %%
zero_pts = merged_df.loc[merged_df['points']==0.0]
zero_pts.iloc[:,0:18].head()

# %%
null_pts = merged_df[merged_df['points'].isnull()]
null_pts['score'].value_counts().head()

# %%
perf_score = merged_df[merged_df['score']==100]
perf_score['points'].value_counts(dropna=False)

# %% [markdown]
# * Null doesn't necessarily mean that the restaurants got perfect sores
# * Score of 100 doesn't necessarily mean that the points is 0 or Nan......
# * So there is some transcription error.....
#
# * How do I deal with this??? ASK MENTOR!!!

# %%
print(merged_df[(merged_df['points']==2) &(merged_df['score']==100)])
merged_df[merged_df['serial_number']=='DABH9GD40']

# %%
sns.kdeplot(data = dropped_dup, x = 'score', hue = 'pe_description')

# %% [markdown]
# ###  Look at Score Distribution on Dropped Duplicate Serial Number!

# %%
merged_df[('violation_code','violation_id')].unique()
